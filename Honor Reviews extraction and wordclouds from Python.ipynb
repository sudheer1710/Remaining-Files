# %% [markdown]
# # Udemy Amazon Reviews extraction

# %%
import requests # Importing requests to extract content from a url

# %%
from bs4 import BeautifulSoup as bs
import re

# %%
import nltk
from nltk.corpus import stopwords

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# creating empty reviews list
honor_reviews=[]
#forest = ["the","king","of","jungle"]

# %%
# Data extraction - Amazon reviews extraction

# %%
for i in range(1,11):
    ip=[]
    url = "https://www.amazon.in/Honor-Sapphire-Blue-128GB-Storage/product-reviews/B07V7ZWFJB/ref=cm_cr_getr_d_paging_btm_prev"
    if i==1:
        url = url+"_"+str(i)+"?ie=UTF8&reviewerType=all_reviews&pageNumber="+str(i)
    else:
        url = url+"_"+str(i)+"?ie=UTF8&reviewerType=all_reviews&pageNumber="+str(i)
    #print(url)
    response = requests.get(url)
    soup = bs(response.content, "html.parser")# creating soup object to iterate over the extracted content
    reviews = soup.findAll("span", attrs={"class","a-size-base review-text review-text-content"})# Extracting the content under specific 
    for i in range(len(reviews)):
        honor_reviews.append(reviews[i].text)
print(honor_reviews)# adding the reviews of one page to empty list which in future contai
# Out:
# ['\nVery bad performance\n', "\nWriting this review after almost 4 months of use.This is a very, VERY good phone and the value for money is solid, you can't go wrong with this. Battery backup is reliable, the UI and performance hasn't given me any issues so far, multitasking and gaming works really well too. Yes, the display could've been better as it's not (there are better displays in the market in this price range). The speaker quality is also below par but it's not that big of an issue. If Display is AN ABSOLUTE DEAL BREAKER OR MAKER for you, I suggest you look into other options (still I'll put in a positive word for Honor saying that the display is a 7/10 in my opinion).Rest, this phone ticks the boxes: design, camera, looks, punch hole front camera is actually good (for people like me who don't prefer pop up front cameras)FINAL WORD: HONOR 20 IS DEFINITELY WORTH BUYING\n", "\nThis is my first I'm writing about any product on amazon..cause i have been waiting for this..I loved this..this is my dream phone... everything is very awesome..it feels premium..camera has 60fps recording.. it's insanely stabilized and picture quality is alslo good...yes it takes not that sharp picture in indoors..but that might get fixed in new updates.. battery life is also good..phone gets full charged 95 pec in 45-50mins..phone feels very premium..it has punch hole whcih is different from other notch and popup.. it's the best under 23k..u r gett5 a 36k phone at just 23k..go for it... don't think twice.. amazon safe packing will make the process sare so that no one can take out the phone and put rocks into the box😂.. don't worry about handling..amazon h na😏😏\n", "\nWell I have been using this phone from quite some time now. and this is my honest review, It handles multi tasking without any issue as i love to play PUBG and in this phone i cant find any lag or any frame drops it gives you best experience. if i talk about camera, it has one of the best camera setup and personally in love with the Macro Shot feature its just amazing. 4000mAh battery with fast charge i didn't find any issue it gives you a day back up very easily. Overall i am very much satisfied - will say a good buy.\n", '\nVery good hardware as well as software. Build quality is superb. I am very happy with the performance. Far better than other Chinese brand cell phones.\n', '\nProduct is okScreen looks bigLighting is superDisplay excellentI think my previous mobile huwaie p20 lite is better than this in screen size n looks wise\n', '\nAlways great by Honor\n', '\nGrate phone by honor😄😄\n', "\nBest camera phone for most use cases.. experience is good.. Negatives are no amoled, can't trust honor for OS updates.. they left honor play with just one update..This is Best camera phone under 35k, best overall phone under 25k, if you don't mind lcd screen\n", '\nBattery Life and Charging Speed Is V.Good .Camera Quality is Also Good But If You Capture Photo And Zoom In Not Sharper and HDR is Okey.Not Support GCam About Gaming you playLow Grafics :  Extreme |  GreatUptoHDR : Ultra | Fream DropAfter 11 day Facing Lag Issue .\n', '\nFingerprint reader is new feature... Very comfortable... Good camera quality... Long battery life... Fast charger... All these qualities make this mobile unique... I m fully satisfied...\n', '\nNo negative comments about this phone, when u hold this in ur hand feels like u r holding something like diamond and touch working is very smooth and nyc camera, it can easily beat the features of one plus 7 and it deserves to be more than that,I suggest just go for it 😊.\n', "\n\xa0Very smooth to daily life activities and outstanding gaming performances.I think it's all about the remarkable kirin 980. 🔥Stunning camera performances far better as i expected after having the recent updates👌.Compare with google pixel 4xl and God's swear the results are almost similar.😌At first use this phone for one day then believe me.👍\n", "\n\xa0The camera quality is superb under bright l ...

# %%
honor_reviews
# Out:
# ['\nVery bad performance\n',
#  "\nWriting this review after almost 4 months of use.This is a very, VERY good phone and the value for money is solid, you can't go wrong with this. Battery backup is reliable, the UI and performance hasn't given me any issues so far, multitasking and gaming works really well too. Yes, the display could've been better as it's not (there are better displays in the market in this price range). The speaker quality is also below par but it's not that big of an issue. If Display is AN ABSOLUTE DEAL BREAKER OR MAKER for you, I suggest you look into other options (still I'll put in a positive word for Honor saying that the display is a 7/10 in my opinion).Rest, this phone ticks the boxes: design, camera, looks, punch hole front camera is actually good (for people like me who don't prefer pop up front cameras)FINAL WORD: HONOR 20 IS DEFINITELY WORTH BUYING\n",
#  "\nThis is my first I'm writing about any product on amazon..cause i have been waiting for this..I loved this..this is my dream phone... everything is very awesome..it feels premium..camera has 60fps recording.. it's insanely stabilized and picture quality is alslo good...yes it takes not that sharp picture in indoors..but that might get fixed in new updates.. battery life is also good..phone gets full charged 95 pec in 45-50mins..phone feels very premium..it has punch hole whcih is different from other notch and popup.. it's the best under 23k..u r gett5 a 36k phone at just 23k..go for it... don't think twice.. amazon safe packing will make the process sare so that no one can take out the phone and put rocks into the box😂.. don't worry about handling..amazon h na😏😏\n",
#  "\nWell I have been using this phone from quite some time now. and this is my honest review, It handles multi tasking without any issue as i love to play PUBG and in this phone i cant find any lag or any frame drops it gives you best experience. if i talk about camera, it has one of the best camera setup and personally in love with the Macro Shot feature its just amazing. 4000mAh battery with fast charge i didn't find any issue it gives you a day back up very easily. Overall i am very much satisfied - will say a good buy.\n",
#  '\nVery good hardware as well as software. Build quality is superb. I am very happy with the performance. Far better than other Chinese brand cell phones.\n',
#  '\nProduct is okScreen looks bigLighting is superDisplay excellentI think my previous mobile huwaie p20 lite is better than this in screen size n looks wise\n',
#  '\nAlways great by Honor\n',
#  '\nGrate phone by honor😄😄\n',
#  "\nBest camera phone for most use cases.. experience is good.. Negatives are no amoled, can't trust honor for OS updates.. they left honor play with just one update..This is Best camera phone under 35k, best overall phone under 25k, if you don't mind lcd screen\n",
#  '\nBattery Life and Charging Speed Is V.Good .Camera Quality is Also Good But If You Capture Photo And Zoom In Not Sharper and HDR is Okey.Not Support GCam About Gaming you playLow Grafics :  Extreme |  GreatUptoHDR : Ultra | Fream DropAfter 11 day Facing Lag Issue .\n',
#  '\nFingerprint reader is new feature... Very comfortable... Good camera quality... Long battery life... Fast charger... All these qualities make this mobile unique... I m fully satisfied...\n',
#  '\nNo negative comments about this phone, when u hold this in ur hand feels like u r holding something like diamond and touch working is very smooth and nyc camera, it can easily beat the features of one plus 7 and it deserves to be more than that,I suggest just go for it 😊.\n',
#  "\n\xa0Very smooth to daily life activities and outstanding gaming performances.I think it's all about the remarkable kirin 980. 🔥Stunning camera performances far better as i expected after having the recent updates👌.Compare with google pixel 4xl and God's swear the results are almost similar.😌At first use this phone for one day then believe me.👍\n",
#  "\n\xa0The camera quality is superb under bright light. However, the front camera is lacking. So if you are into taking selfies, might not be for you. Fingerprints sensor works great and it's convenient as well because of the position.\n",
#  "\nIt's a good device if u want to use this for gaming. Performance is very good given the price. I wil always recommend this over other phones in this price segment. Incase u thinking of buying this don't see reviews that there in YouTube because most of the reviews are based on general perspective. Its a phone for someone who wants to be in budget but still wants a device for intensive gaming experience.\n",
#  '\nReally good phone for the price and love tha camera with the 40 watt fast charging\n',
#  '\nPhone had problemBut amazon is best they have helped me in returning product\n',
#  "\nAfter 2 months of usage I can say it's just perfect. Everything works well and great battery and camera. Processor as smooth as apple. Fits well in hand and responsive.\n",
#  "\nI'm really disappointed by Honor just because of screen. I don't know why but screen was broke when mobile fell from less than height of 1 feet only.\n",
#  '\nThe best you can get under 23k, I got it for 21.5k after CC discount.... Camera is the best under 35k segment.  UI also feels premium, Processor is best you can get under 40k segment...You can easily handle with one hand and weight is pretty less compared to oppo, Asus, one plus mobiles ...\n',
#  '\nThis is my second phone of Honor after 6x and it is amazing\n',
#  '\nAll-rounder phone except super amoled display.\n',
#  '\nGood\n',
#  '\nThe Phone is amazing, especially at this value of Rs. 22,999. Flagship processor, crisp display, beast battery life. Camera can be a little iffy in low lighting, but otherwise the pictures are very good. Would definitely recommend that you go ahead and buy it without a worry.\n',
#  '\nPros - display , camera , battery life , performance , surprisingly attached plastic film also on temper glassCons - in hand feel could be better ( like oneplus 5 ), only 2 color options ,\n',
#  '\nI just love it. As promised, I have received my android 10 update. Phone is running smoothly. No lag at all. Very handy size. Camera is awesome. Great phone from Honor\n',
#  '\nPhone is very good, camera also very nice , Bettery 1 दिन nikal है aram, charging also very fast 👌👌\n',
#  '\nMy life 1st amazing mobile phone\n',
#  '\nThe phone has very nice look, has very good camera quality, and the processor is too good powerful & run heavy games smoothly, overall a nice experience to use this phone\n',
#  '\nAfter using the phone for a months and long I could say it is a nice buy.Just little disappointed with camera.  I find it takes a little dark photos than other mobile.\n',
#  '\nBest product as compare to other mid range brands available with best display and camera quality moreover camera is superb, premium feel,best features.only problem is with battery as battery drain at high speed when we play games and other tasks. Overall product is superb\n',
#  '\nBought this phone couple of months ago, and I am reviewing after using it. Really good buy, camera, battery, fingerprint and overall performance is excellant!\n',
#  '\nIt immediately loose net connection after use 20 minute of youtube surfing\n',
#  '\nSurprisingly wonderfull in this cost for which Oneplus is charging 50000..Aankh bund kar purchase karein..Befikra ho kar..\n',
#  '\nVery nice product. Camera, battery, display all awesome package.\n',
#  '\nGood product\n',
#  '\nExcellent, totally satisfied\n',
#  '\nSuper quality camera selfie & wide angle shot, night mode all so very well\n',
#  '\nExcellent product\n',
#  '\nGood product. All features work well. Havent used much but looks, feels and works well.\n',
#  '\nspeed, finger print reader, camera,battery life is too good. Best compact and quality mobile at this price range.\n',
#  "\nLove the Honor :) i like this phone . It's good for gaming and photography . I was skeptical about side fingerprint reader when purchased but it is working fine and i have no issue with it now it feels normal\n",
#  '\nWonder machine at this pricePremium one\n',
#  '\nProcessor and battery performance is awesome but some disappointment by the rear camera otherwise just awesome.........\n',
#  '\nQuite happy with the performance of the product. Significant upgrade from previous generation with regards to camera quality, processing speed and battery life. A good buy for this price range (22k inr).\n',
#  '\nI like finger print in this phone\n',
#  '\nAll good except fingerprint scanner..It scans my finger 6/10 times which is really poor for this phone.\n',
#  '\nSome hardware problem detected\n',
#  '\nSuper charge is very good.Camera quality is not upto the mark.Battery life is not as expected.Incoming call still appear on the screen when do not disturb mode is on.\n',
#  "\nAt 22999 it's the best you can get friends don't go for any other than this phone if your budget is under 25000 everything in this phone is best wonderful user experience it's giving.\n",
#  '\nSuperfast Processor, good battery life\n',
#  '\nGreat phone\n',
#  '\nFlagship product from honorWhen use this product you feel the smothness and also phone is very very fast. Camera quality is above edges..\n',
#  "\nHeating, and no replace or return from amazon. Don't buy from amazon now they have changed their policies.\n",
#  '\nThe phone is really worth buying\n',
#  '\nHonor 20 has 48mega pixel camera but it the pictures i had taken with full pixel is kind a blur, in short with this price, camera is not worth it.\n',
#  '\nBuilt quality, camera, battery life, performance the best in market under 23k\n',
#  '\nVery good\n',
#  '\nCamera is excellent. No negatives for camera.\n',
#  '\nGreat phone. Battery life superb. Camera not that good. But still wrking fr me. Overall 8/10.\n',
#  '\nGreat 8\n',
#  '\nNo doubt according to price best smart phone ever but honor wants give more filter in camera and improve bettery performance\n',
#  '\nHonour 20 best phone under 20000\n',
#  '\nThanks AmazonValue for moneyThanks honor for great product in budget\n',
#  '\nNice product.Equal to one plus\n',
#  '\nThis is a really Great phone...\n',
#  '\nWithout any single thought go for it.\n',
#  '\ncamera focussing isnot proper\n',
#  '\nVery good, I am very happy 😊 😊 😊\n',
#  '\nIt started crashing within a week\n',
#  '\nWorthy purchase 23k, feels a bit bulk but handy. Quad cam setup looks promising. Premium mobile in budget price.\n',
#  '\nBest cell phone ever in your budget\n',
#  '\nVery good quality and good fingerprint sensor\n',
#  "\nIts so fast that i don't use my face unlock any more. 🔓😁The best device in this range\n",
#  '\nExcellent\n',
#  '\n"fingerprint reader" is very faster... Battery is good...it\'s awesome mobile phone....\n',
#  '\nMobile was good... But need improvement on processor should be comparable with Snapdragon 855+\n',
#  '\nGood\n',
#  '\nI like the sensor of the fingerprint and battery  life\n',
#  '\nPerformance superb after android 10....of course you buy it... In this bughet\n']

# %%
# Data cleansing and Wordcloud

# %%
# writing reviews in a text file

# %%
with open("honor_reviews.txt","w",encoding='utf8') as output:
    output.write(str(honor_reviews))

# %%
# Joining all the reviews into single paragraph
ip_rev_string = " ".join(honor_reviews)

# %%
ip_rev_string
# Out:
# '\nVery bad performance\n \nWriting this review after almost 4 months of use.This is a very, VERY good phone and the value for money is solid, you can\'t go wrong with this. Battery backup is reliable, the UI and performance hasn\'t given me any issues so far, multitasking and gaming works really well too. Yes, the display could\'ve been better as it\'s not (there are better displays in the market in this price range). The speaker quality is also below par but it\'s not that big of an issue. If Display is AN ABSOLUTE DEAL BREAKER OR MAKER for you, I suggest you look into other options (still I\'ll put in a positive word for Honor saying that the display is a 7/10 in my opinion).Rest, this phone ticks the boxes: design, camera, looks, punch hole front camera is actually good (for people like me who don\'t prefer pop up front cameras)FINAL WORD: HONOR 20 IS DEFINITELY WORTH BUYING\n \nThis is my first I\'m writing about any product on amazon..cause i have been waiting for this..I loved this..this is my dream phone... everything is very awesome..it feels premium..camera has 60fps recording.. it\'s insanely stabilized and picture quality is alslo good...yes it takes not that sharp picture in indoors..but that might get fixed in new updates.. battery life is also good..phone gets full charged 95 pec in 45-50mins..phone feels very premium..it has punch hole whcih is different from other notch and popup.. it\'s the best under 23k..u r gett5 a 36k phone at just 23k..go for it... don\'t think twice.. amazon safe packing will make the process sare so that no one can take out the phone and put rocks into the box😂.. don\'t worry about handling..amazon h na😏😏\n \nWell I have been using this phone from quite some time now. and this is my honest review, It handles multi tasking without any issue as i love to play PUBG and in this phone i cant find any lag or any frame drops it gives you best experience. if i talk about camera, it has one of the best camera setup and personally in love with the Macro Shot feature its just amazing. 4000mAh battery with fast charge i didn\'t find any issue it gives you a day back up very easily. Overall i am very much satisfied - will say a good buy.\n \nVery good hardware as well as software. Build quality is superb. I am very happy with the performance. Far better than other Chinese brand cell phones.\n \nProduct is okScreen looks bigLighting is superDisplay excellentI think my previous mobile huwaie p20 lite is better than this in screen size n looks wise\n \nAlways great by Honor\n \nGrate phone by honor😄😄\n \nBest camera phone for most use cases.. experience is good.. Negatives are no amoled, can\'t trust honor for OS updates.. they left honor play with just one update..This is Best camera phone under 35k, best overall phone under 25k, if you don\'t mind lcd screen\n \nBattery Life and Charging Speed Is V.Good .Camera Quality is Also Good But If You Capture Photo And Zoom In Not Sharper and HDR is Okey.Not Support GCam About Gaming you playLow Grafics :  Extreme |  GreatUptoHDR : Ultra | Fream DropAfter 11 day Facing Lag Issue .\n \nFingerprint reader is new feature... Very comfortable... Good camera quality... Long battery life... Fast charger... All these qualities make this mobile unique... I m fully satisfied...\n \nNo negative comments about this phone, when u hold this in ur hand feels like u r holding something like diamond and touch working is very smooth and nyc camera, it can easily beat the features of one plus 7 and it deserves to be more than that,I suggest just go for it 😊.\n \n\xa0Very smooth to daily life activities and outstanding gaming performances.I think it\'s all about the remarkable kirin 980. 🔥Stunning camera performances far better as i expected after having the recent updates👌.Compare with google pixel 4xl and God\'s swear the results are almost similar.😌At first use this phone for one day then believe me.👍\n \n\xa0The camera quality is superb under bright light. However, the fron ...

# %%
# Removing unwanted symbols incase if exists
ip_rev_string = re.sub("[^A-Za-z" "]+"," ",ip_rev_string).lower()
ip_rev_string = re.sub("[0-9" "]+"," ",ip_rev_string)
ip_rev_string = re.sub('(\\b[A-Za-z] \\b|\\b [A-Za-z]\\b)', '', ip_rev_string)

# %%
ip_rev_string
# Out:
# ' very bad performance writing this review after almost months of use this is very very good phone and the value for money is solid you can go wrong with this battery backup is reliable the ui and performance hasn given me any issues so far multitasking and gaming works really well too yes the display could ve been better as it not there are better displays in the market in this price range the speaker quality is also below par but it not that big of an issue if display is an absolute deal breaker or maker for you suggest you look into other options still ll put in positive word for honor saying that the display is in my opinion rest this phone ticks the boxes design camera looks punch hole front camera is actually good for people like me who don prefer pop up front cameras final word honor is definitely worth buying this is my first writing about any product on amazon cause have been waiting for this loved this this is my dream phone everything is very awesome it feels premium camera has fps recording it insanely stabilized and picture quality is alslo good yes it takes not that sharp picture in indoors but that might get fixed in new updates battery life is also good phone gets full charged pec in mins phone feels very premium it has punch hole whcih is different from other notch and popup it the best under gett phone at just go for it don think twice amazon safe packing will make the process sare so that no one can take out the phone and put rocks into the box don worry about handling amazon na well have been using this phone from quite some time now and this is my honest review it handles multi tasking without any issue as love to play pubg and in this phone cant find any lag or any frame drops it gives you best experience if talk about camera it has one of the best camera setup and personally in love with the macro shot feature its just amazing mah battery with fast charge didn find any issue it gives you day back up very easily overall am very much satisfied will say good buy very good hardware as well as software build quality is superb am very happy with the performance far better than other chinese brand cell phones product is okscreen looks biglighting is superdisplay excellenti think my previous mobile huwaie lite is better than this in screen size looks wise always great by honor grate phone by honor best camera phone for most use cases experience is good negatives are no amoled can trust honor for os updates they left honor play with just one update this is best camera phone under best overall phone under if you don mind lcd screen battery life and charging speed is good camera quality is also good but if you capture photo and zoom in not sharper and hdr is okey not support gcam about gaming you playlow grafics extreme greatuptohdr ultra fream dropafter day facing lag issue fingerprint reader is new feature very comfortable good camera quality long battery life fast charger all these qualities make this mobile unique fully satisfied no negative comments about this phone when hold this in ur hand feels like holding something like diamond and touch working is very smooth and nyc camera it can easily beat the features of one plus and it deserves to be more than that suggest just go for it very smooth to daily life activities and outstanding gaming performances think it all about the remarkable kirin stunning camera performances far better as expected after having the recent updates compare with google pixel xl and god swear the results are almost similar at first use this phone for one day then believe me the camera quality is superb under bright light however the front camera is lacking so if you are into taking selfies might not be for you fingerprints sensor works great and it convenient as well because of the position it good device if want to use this for gaming performance is very good given the price wil always recommend this over other phones in this price segment incase thinking of buying this don see review ...

# %%
# words that contained in iphone 8 plus reviews
ip_reviews_words = ip_rev_string.split(" ")

# %%
ip_reviews_words
# Out:
# ['',
#  'very',
#  'bad',
#  'performance',
#  'writing',
#  'this',
#  'review',
#  'after',
#  'almost',
#  'months',
#  'of',
#  'use',
#  'this',
#  'is',
#  'very',
#  'very',
#  'good',
#  'phone',
#  'and',
#  'the',
#  'value',
#  'for',
#  'money',
#  'is',
#  'solid',
#  'you',
#  'can',
#  'go',
#  'wrong',
#  'with',
#  'this',
#  'battery',
#  'backup',
#  'is',
#  'reliable',
#  'the',
#  'ui',
#  'and',
#  'performance',
#  'hasn',
#  'given',
#  'me',
#  'any',
#  'issues',
#  'so',
#  'far',
#  'multitasking',
#  'and',
#  'gaming',
#  'works',
#  'really',
#  'well',
#  'too',
#  'yes',
#  'the',
#  'display',
#  'could',
#  've',
#  'been',
#  'better',
#  'as',
#  'it',
#  'not',
#  'there',
#  'are',
#  'better',
#  'displays',
#  'in',
#  'the',
#  'market',
#  'in',
#  'this',
#  'price',
#  'range',
#  'the',
#  'speaker',
#  'quality',
#  'is',
#  'also',
#  'below',
#  'par',
#  'but',
#  'it',
#  'not',
#  'that',
#  'big',
#  'of',
#  'an',
#  'issue',
#  'if',
#  'display',
#  'is',
#  'an',
#  'absolute',
#  'deal',
#  'breaker',
#  'or',
#  'maker',
#  'for',
#  'you',
#  'suggest',
#  'you',
#  'look',
#  'into',
#  'other',
#  'options',
#  'still',
#  'll',
#  'put',
#  'in',
#  'positive',
#  'word',
#  'for',
#  'honor',
#  'saying',
#  'that',
#  'the',
#  'display',
#  'is',
#  'in',
#  'my',
#  'opinion',
#  'rest',
#  'this',
#  'phone',
#  'ticks',
#  'the',
#  'boxes',
#  'design',
#  'camera',
#  'looks',
#  'punch',
#  'hole',
#  'front',
#  'camera',
#  'is',
#  'actually',
#  'good',
#  'for',
#  'people',
#  'like',
#  'me',
#  'who',
#  'don',
#  'prefer',
#  'pop',
#  'up',
#  'front',
#  'cameras',
#  'final',
#  'word',
#  'honor',
#  'is',
#  'definitely',
#  'worth',
#  'buying',
#  'this',
#  'is',
#  'my',
#  'first',
#  'writing',
#  'about',
#  'any',
#  'product',
#  'on',
#  'amazon',
#  'cause',
#  'have',
#  'been',
#  'waiting',
#  'for',
#  'this',
#  'loved',
#  'this',
#  'this',
#  'is',
#  'my',
#  'dream',
#  'phone',
#  'everything',
#  'is',
#  'very',
#  'awesome',
#  'it',
#  'feels',
#  'premium',
#  'camera',
#  'has',
#  'fps',
#  'recording',
#  'it',
#  'insanely',
#  'stabilized',
#  'and',
#  'picture',
#  'quality',
#  'is',
#  'alslo',
#  'good',
#  'yes',
#  'it',
#  'takes',
#  'not',
#  'that',
#  'sharp',
#  'picture',
#  'in',
#  'indoors',
#  'but',
#  'that',
#  'might',
#  'get',
#  'fixed',
#  'in',
#  'new',
#  'updates',
#  'battery',
#  'life',
#  'is',
#  'also',
#  'good',
#  'phone',
#  'gets',
#  'full',
#  'charged',
#  'pec',
#  'in',
#  'mins',
#  'phone',
#  'feels',
#  'very',
#  'premium',
#  'it',
#  'has',
#  'punch',
#  'hole',
#  'whcih',
#  'is',
#  'different',
#  'from',
#  'other',
#  'notch',
#  'and',
#  'popup',
#  'it',
#  'the',
#  'best',
#  'under',
#  'gett',
#  'phone',
#  'at',
#  'just',
#  'go',
#  'for',
#  'it',
#  'don',
#  'think',
#  'twice',
#  'amazon',
#  'safe',
#  'packing',
#  'will',
#  'make',
#  'the',
#  'process',
#  'sare',
#  'so',
#  'that',
#  'no',
#  'one',
#  'can',
#  'take',
#  'out',
#  'the',
#  'phone',
#  'and',
#  'put',
#  'rocks',
#  'into',
#  'the',
#  'box',
#  'don',
#  'worry',
#  'about',
#  'handling',
#  'amazon',
#  'na',
#  'well',
#  'have',
#  'been',
#  'using',
#  'this',
#  'phone',
#  'from',
#  'quite',
#  'some',
#  'time',
#  'now',
#  'and',
#  'this',
#  'is',
#  'my',
#  'honest',
#  'review',
#  'it',
#  'handles',
#  'multi',
#  'tasking',
#  'without',
#  'any',
#  'issue',
#  'as',
#  'love',
#  'to',
#  'play',
#  'pubg',
#  'and',
#  'in',
#  'this',
#  'phone',
#  'cant',
#  'find',
#  'any',
#  'lag',
#  'or',
#  'any',
#  'frame',
#  'drops',
#  'it',
#  'gives',
#  'you',
#  'best',
#  'experience',
#  'if',
#  'talk',
#  'about',
#  'camera',
#  'it',
#  'has',
#  'one',
#  'of',
#  'the',
#  'best',
#  'camera',
#  'setup',
#  'and',
#  'personally',
#  'in',
#  'love',
#  'with',
#  'the',
#  'macro',
#  'shot',
#  'feature',
#  'its',
#  'just',
#  'amazing',
#  'mah',
#  'battery',
#  'with',
#  'fast',
#  'charge',
#  'didn',
#  'find',
#  'any',
#  'issue',
#  'it',
#  'gives',
#  'you',
#  'day',
#  'back',
#  'up',
#  'very',
#  'easily',
#  'overall',
#  'am',
#  'very',
#  'much',
#  'satisfied',
#  'will',
#  'say',
#  'good',
#  'buy',
#  'very',
#  'good',
#  'hardware',
#  'as',
#  'well',
#  'as',
#  'software',
#  'build',
#  'quality',
#  'is',
#  'superb',
#  'am',
#  'very',
#  'happy',
#  'with',
#  'the',
#  'performance',
#  'far',
#  'better',
#  'than',
#  'other',
#  'chinese',
#  'brand',
#  'cell',
#  'phones',
#  'product',
#  'is',
#  'okscreen',
#  'looks',
#  'biglighting',
#  'is',
#  'superdisplay',
#  'excellenti',
#  'think',
#  'my',
#  'previous',
#  'mobile',
#  'huwaie',
#  'lite',
#  'is',
#  'better',
#  'than',
#  'this',
#  'in',
#  'screen',
#  'size',
#  'looks',
#  'wise',
#  'always',
#  'great',
#  'by',
#  'honor',
#  'grate',
#  'phone',
#  'by',
#  'honor',
#  'best',
#  'camera',
#  'phone',
#  'for',
#  'most',
#  'use',
#  'cases',
#  'experience',
#  'is',
#  'good',
#  'negatives',
#  'are',
#  'no',
#  'amoled',
#  'can',
#  'trust',
#  'honor',
#  'for',
#  'os',
#  'updates',
#  'they',
#  'left',
#  'honor',
#  'play',
#  'with',
#  'just',
#  'one',
#  'update',
#  'this',
#  'is',
#  'best',
#  'camera',
#  'phone',
#  'under',
#  'best',
#  'overall',
#  'phone',
#  'under',
#  'if',
#  'you',
#  'don',
#  'mind',
#  'lcd',
#  'screen',
#  'battery',
#  'life',
#  'and',
#  'charging',
#  'speed',
#  'is',
#  'good',
#  'camera',
#  'quality',
#  'is',
#  'also',
#  'good',
#  'but',
#  'if',
#  'you',
#  'capture',
#  'photo',
#  'and',
#  'zoom',
#  'in',
#  'not',
#  'sharper',
#  'and',
#  'hdr',
#  'is',
#  'okey',
#  'not',
#  'support',
#  'gcam',
#  'about',
#  'gaming',
#  'you',
#  'playlow',
#  'grafics',
#  'extreme',
#  'greatuptohdr',
#  'ultra',
#  'fream',
#  'dropafter',
#  'day',
#  'facing',
#  'lag',
#  'issue',
#  'fingerprint',
#  'reader',
#  'is',
#  'new',
#  'feature',
#  'very',
#  'comfortable',
#  'good',
#  'camera',
#  'quality',
#  'long',
#  'battery',
#  'life',
#  'fast',
#  'charger',
#  'all',
#  'these',
#  'qualities',
#  'make',
#  'this',
#  'mobile',
#  'unique',
#  'fully',
#  'satisfied',
#  'no',
#  'negative',
#  'comments',
#  'about',
#  'this',
#  'phone',
#  'when',
#  'hold',
#  'this',
#  'in',
#  'ur',
#  'hand',
#  'feels',
#  'like',
#  'holding',
#  'something',
#  'like',
#  'diamond',
#  'and',
#  'touch',
#  'working',
#  'is',
#  'very',
#  'smooth',
#  'and',
#  'nyc',
#  'camera',
#  'it',
#  'can',
#  'easily',
#  'beat',
#  'the',
#  'features',
#  'of',
#  'one',
#  'plus',
#  'and',
#  'it',
#  'deserves',
#  'to',
#  'be',
#  'more',
#  'than',
#  'that',
#  'suggest',
#  'just',
#  'go',
#  'for',
#  'it',
#  'very',
#  'smooth',
#  'to',
#  'daily',
#  'life',
#  'activities',
#  'and',
#  'outstanding',
#  'gaming',
#  'performances',
#  'think',
#  'it',
#  'all',
#  'about',
#  'the',
#  'remarkable',
#  'kirin',
#  'stunning',
#  'camera',
#  'performances',
#  'far',
#  'better',
#  'as',
#  'expected',
#  'after',
#  'having',
#  'the',
#  'recent',
#  'updates',
#  'compare',
#  'with',
#  'google',
#  'pixel',
#  'xl',
#  'and',
#  'god',
#  'swear',
#  'the',
#  'results',
#  'are',
#  'almost',
#  'similar',
#  'at',
#  'first',
#  'use',
#  'this',
#  'phone',
#  'for',
#  'one',
#  'day',
#  'then',
#  'believe',
#  'me',
#  'the',
#  'camera',
#  'quality',
#  'is',
#  'superb',
#  'under',
#  'bright',
#  'light',
#  'however',
#  'the',
#  'front',
#  'camera',
#  'is',
#  'lacking',
#  'so',
#  'if',
#  'you',
#  'are',
#  'into',
#  'taking',
#  'selfies',
#  'might',
#  'not',
#  'be',
#  'for',
#  'you',
#  'fingerprints',
#  'sensor',
#  'works',
#  'great',
#  'and',
#  'it',
#  'convenient',
#  'as',
#  'well',
#  'because',
#  'of',
#  'the',
#  'position',
#  'it',
#  'good',
#  'device',
#  'if',
#  'want',
#  'to',
#  'use',
#  'this',
#  'for',
#  'gaming',
#  'performance',
#  'is',
#  'very',
#  'good',
#  'given',
#  'the',
#  'price',
#  'wil',
#  'always',
#  'recommend',
#  'this',
#  'over',
#  'other',
#  'phones',
#  'in',
#  'this',
#  'price',
#  'segment',
#  'incase',
#  'thinking',
#  'of',
#  'buying',
#  'this',
#  'don',
#  'see',
#  'reviews',
#  'that',
#  'there',
#  'in',
#  'youtube',
#  'because',
#  'most',
#  'of',
#  'the',
#  'reviews',
#  'are',
#  'based',
#  'on',
#  'general',
#  'perspective',
#  'its',
#  'phone',
#  'for',
#  'someone',
#  'who',
#  'wants',
#  'to',
#  'be',
#  'in',
#  'budget',
#  'but',
#  'still',
#  'wants',
#  'device',
#  'for',
#  'intensive',
#  'gaming',
#  'experience',
#  'really',
#  'good',
#  'phone',
#  'for',
#  'the',
#  'price',
#  'and',
#  'love',
#  'tha',
#  'camera',
#  'with',
#  'the',
#  'watt',
#  'fast',
#  'charging',
#  'phone',
#  'had',
#  'problembut',
#  'amazon',
#  'is',
#  'best',
#  'they',
#  'have',
#  'helped',
#  'me',
#  'in',
#  'returning',
#  'product',
#  'after',
#  'months',
#  'of',
#  'usage',
#  'can',
#  'say',
#  'it',
#  'just',
#  'perfect',
#  'everything',
#  'works',
#  'well',
#  'and',
#  'great',
#  'battery',
#  'and',
#  'camera',
#  'processor',
#  'as',
#  'smooth',
#  'as',
#  'apple',
#  'fits',
#  'well',
#  'in',
#  'hand',
#  'and',
#  'responsive',
#  'really',
#  'disappointed',
#  'by',
#  'honor',
#  'just',
#  'because',
#  'of',
#  'screen',
#  'don',
#  'know',
#  'why',
#  'but',
#  'screen',
#  'was',
#  'broke',
#  'when',
#  'mobile',
#  'fell',
#  'from',
#  'less',
#  'than',
#  'height',
#  'of',
#  'feet',
#  'only',
#  'the',
#  'best',
#  'you',
#  'can',
#  'get',
#  'under',
#  'got',
#  'it',
#  'for',
#  'after',
#  'cc',
#  'discount',
#  'camera',
#  'is',
#  'the',
#  'best',
#  'under',
#  'segment',
#  'ui',
#  'also',
#  'feels',
#  'premium',
#  'processor',
#  'is',
#  'best',
#  'you',
#  'can',
#  'get',
#  'under',
#  'segment',
#  'you',
#  'can',
#  'easily',
#  'handle',
#  'with',
#  'one',
#  'hand',
#  'and',
#  'weight',
#  'is',
#  'pretty',
#  'less',
#  'compared',
#  'to',
#  'oppo',
#  'asus',
#  'one',
#  'plus',
#  'mobiles',
#  'this',
#  'is',
#  'my',
#  'second',
#  'phone',
#  'of',
#  'honor',
#  'after',
#  'and',
#  'it',
#  'is',
#  'amazing',
#  'all',
#  'rounder',
#  'phone',
#  'except',
#  'super',
#  'amoled',
#  'display',
#  'good',
#  'the',
#  'phone',
#  'is',
#  'amazing',
#  'especially',
#  'at',
#  'this',
#  'value',
#  'of',
#  'rs',
#  'flagship',
#  'processor',
#  'crisp',
#  'display',
#  'beast',
#  'battery',
#  'life',
#  'camera',
#  'can',
#  'be',
#  'little',
#  'iffy',
#  'in',
#  'low',
#  'lighting',
#  'but',
#  'otherwise',
#  'the',
#  'pictures',
#  'are',
#  'very',
#  'good',
#  'would',
#  'definitely',
#  'recommend',
#  'that',
#  'you',
#  'go',
#  'ahead',
#  'and',
#  'buy',
#  'it',
#  'without',
#  'worry',
#  'pros',
#  'display',
#  'camera',
#  'battery',
#  'life',
#  'performance',
#  'surprisingly',
#  'attached',
#  'plastic',
#  'film',
#  'also',
#  'on',
#  'temper',
#  'glasscons',
#  'in',
#  'hand',
#  'feel',
#  'could',
#  'be',
#  'better',
#  'like',
#  'oneplus',
#  'only',
#  'color',
#  'options',
#  'just',
#  'love',
#  'it',
#  'as',
#  'promised',
#  'have',
#  'received',
#  'my',
#  'android',
#  'update',
#  'phone',
#  'is',
#  'running',
#  'smoothly',
#  'no',
#  'lag',
#  'at',
#  'all',
#  'very',
#  'handy',
#  'size',
#  'camera',
#  ...]

# %%
# stop_words = stopwords.words('english') can use this command if nltk loaded

# %%
with open("C:\\Users\\V Sudheer Kumar\\stopwords_en.txt") as sw:
    stopwords = sw.read()

# %%
stopwords = stopwords.split("\n")

# %%
temp = ["this","is","awsome","Data","Science"]
[i for i in temp if i not in "is"]
# Out:
# ['this', 'awsome', 'Data', 'Science']

# %%
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'would',
#  'should',
#  'could',
#  'ought',
#  "i'm",
#  "you're",
#  "he's",
#  "she's",
#  "it's",
#  "we're",
#  "they're",
#  "i've",
#  "you've",
#  "we've",
#  "they've",
#  "i'd",
#  "you'd",
#  "he'd",
#  "she'd",
#  "we'd",
#  "they'd",
#  "i'll",
#  "you'll",
#  "he'll",
#  "she'll",
#  "we'll",
#  "they'll",
#  "isn't",
#  "aren't",
#  "wasn't",
#  "weren't",
#  "hasn't",
#  "haven't",
#  "hadn't",
#  "doesn't",
#  "don't",
#  "didn't",
#  "won't",
#  "wouldn't",
#  "shan't",
#  "shouldn't",
#  "can't",
#  'cannot',
#  "couldn't",
#  "mustn't",
#  "let's",
#  "that's",
#  "who's",
#  "what's",
#  "here's",
#  "there's",
#  "when's",
#  "where's",
#  "why's",
#  "how's",
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  '']

# %%
stopwords.append('phone')

# %%
ip_reviews_words = [w for w in ip_reviews_words if not w in stopwords]

# %%
# Joining all the reviews into single paragraph
ip_rev_string = " ".join(ip_reviews_words)

# %%
ip_rev_string
# Out:
# 'bad performance writing review almost months use good value money solid can go wrong battery backup reliable ui performance hasn given issues far multitasking gaming works really well yes display ve better better displays market price range speaker quality also par big issue display absolute deal breaker maker suggest look options still ll put positive word honor saying display opinion rest ticks boxes design camera looks punch hole front camera actually good people like don prefer pop front cameras final word honor definitely worth buying first writing product amazon cause waiting loved dream everything awesome feels premium camera fps recording insanely stabilized picture quality alslo good yes takes sharp picture indoors might get fixed new updates battery life also good gets full charged pec mins feels premium punch hole whcih different notch popup best gett just go don think twice amazon safe packing will make process sare one can take put rocks box don worry handling amazon na well using quite time now honest review handles multi tasking without issue love play pubg cant find lag frame drops gives best experience talk camera one best camera setup personally love macro shot feature just amazing mah battery fast charge didn find issue gives day back easily overall much satisfied will say good buy good hardware well software build quality superb happy performance far better chinese brand cell phones product okscreen looks biglighting superdisplay excellenti think previous mobile huwaie lite better screen size looks wise always great honor grate honor best camera use cases experience good negatives amoled can trust honor os updates left honor play just one update best camera best overall don mind lcd screen battery life charging speed good camera quality also good capture photo zoom sharper hdr okey support gcam gaming playlow grafics extreme greatuptohdr ultra fream dropafter day facing lag issue fingerprint reader new feature comfortable good camera quality long battery life fast charger qualities make mobile unique fully satisfied negative comments hold ur hand feels like holding something like diamond touch working smooth nyc camera can easily beat features one plus deserves suggest just go smooth daily life activities outstanding gaming performances think remarkable kirin stunning camera performances far better expected recent updates compare google pixel xl god swear results almost similar first use one day believe camera quality superb bright light however front camera lacking taking selfies might fingerprints sensor works great convenient well position good device want use gaming performance good given price wil always recommend phones price segment incase thinking buying don see reviews youtube reviews based general perspective someone wants budget still wants device intensive gaming experience really good price love tha camera watt fast charging problembut amazon best helped returning product months usage can say just perfect everything works well great battery camera processor smooth apple fits well hand responsive really disappointed honor just screen don know screen broke mobile fell less height feet best can get got cc discount camera best segment ui also feels premium processor best can get segment can easily handle one hand weight pretty less compared oppo asus one plus mobiles second honor amazing rounder except super amoled display good amazing especially value rs flagship processor crisp display beast battery life camera can little iffy low lighting otherwise pictures good definitely recommend go ahead buy without worry pros display camera battery life performance surprisingly attached plastic film also temper glasscons hand feel better like oneplus color options just love promised received android update running smoothly lag handy size camera awesome great honor good camera also nice bettery nikal aram charging also fast life st amazing mobile nice look good camera quality processor good powerful run hea ...

# %%
# Python3 code to find frequency of each word 

def wordListToFreqDict(wordlist):
    wordfreq = [wordlist.count(p) for p in wordlist]
    return dict(list(zip(wordlist,wordfreq)))

def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

str_list = ip_rev_string.split()

dictionary = wordListToFreqDict(str_list)
sorteddict = sortFreqDict(dictionary)

for s in sorteddict: print(str(s))
# Out:
# (40, 'camera')
# (35, 'good')
# (21, 'best')
# (21, 'battery')
# (15, 'quality')
# (14, 'product')
# (14, 'life')
# (13, 'honor')
# (11, 'performance')
# (10, 'can')
# (9, 'well')
# (9, 'price')
# (9, 'one')
# (9, 'mobile')
# (9, 'just')
# (9, 'great')
# (9, 'don')
# (8, 'use')
# (8, 'display')
# (8, 'also')
# (7, 'really')
# (7, 'processor')
# (7, 'like')
# (7, 'fingerprint')
# (7, 'feels')
# (7, 'buy')
# (6, 'superb')
# (6, 'overall')
# (6, 'nice')
# (6, 'go')
# (6, 'gaming')
# (6, 'fast')
# (6, 'better')
# (6, 'awesome')
# (6, 'amazon')
# (5, 'screen')
# (5, 'range')
# (5, 'premium')
# (5, 'love')
# (5, 'looks')
# (5, 'issue')
# (5, 'experience')
# (5, 'budget')
# (4, 'works')
# (4, 'still')
# (4, 'speed')
# (4, 'reader')
# (4, 'months')
# (4, 'hand')
# (4, 'get')
# (4, 'excellent')
# (4, 'charging')
# (4, 'amazing')
# (3, 'worth')
# (3, 'without')
# (3, 'wants')
# (3, 'using')
# (3, 'updates')
# (3, 'think')
# (3, 'super')
# (3, 'smooth')
# (3, 'sensor')
# (3, 'segment')
# (3, 'say')
# (3, 'satisfied')
# (3, 'plus')
# (3, 'play')
# (3, 'pixel')
# (3, 'now')
# (3, 'little')
# (3, 'lag')
# (3, 'happy')
# (3, 'front')
# (3, 'finger')
# (3, 'find')
# (3, 'feel')
# (3, 'features')
# (3, 'far')
# (3, 'everything')
# (3, 'easily')
# (3, 'device')
# (3, 'day')
# (3, 'buying')
# (2, 'youtube')
# (2, 'yes')
# (2, 'writing')
# (2, 'worry')
# (2, 'working')
# (2, 'word')
# (2, 'will')
# (2, 'value')
# (2, 'update')
# (2, 'ui')
# (2, 'takes')
# (2, 'surprisingly')
# (2, 'suggest')
# (2, 'smoothly')
# (2, 'size')
# (2, 'shot')
# (2, 'setup')
# (2, 'reviews')
# (2, 'review')
# (2, 'recommend')
# (2, 'quite')
# (2, 'put')
# (2, 'purchase')
# (2, 'punch')
# (2, 'problem')
# (2, 'print')
# (2, 'previous')
# (2, 'pictures')
# (2, 'picture')
# (2, 'phones')
# (2, 'performances')
# (2, 'otherwise')
# (2, 'options')
# (2, 'oneplus')
# (2, 'new')
# (2, 'negatives')
# (2, 'much')
# (2, 'mode')
# (2, 'might')
# (2, 'market')
# (2, 'make')
# (2, 'look')
# (2, 'long')
# (2, 'less')
# (2, 'kar')
# (2, 'hole')
# (2, 'hardware')
# (2, 'handy')
# (2, 'gives')
# (2, 'given')
# (2, 'games')
# (2, 'full')
# (2, 'flagship')
# (2, 'first')
# (2, 'feature')
# (2, 'expected')
# (2, 'except')
# (2, 'ever')
# (2, 'disappointed')
# (2, 'definitely')
# (2, 'compare')
# (2, 'charge')
# (2, 'cell')
# (2, 'bettery')
# (2, 'android')
# (2, 'amoled')
# (2, 'always')
# (2, 'almost')
# (1, 'zoom')
# (1, 'xl')
# (1, 'wrong')
# (1, 'wrking')
# (1, 'worthy')
# (1, 'work')
# (1, 'wonderfull')
# (1, 'wonderful')
# (1, 'wonder')
# (1, 'within')
# (1, 'wise')
# (1, 'wil')
# (1, 'wide')
# (1, 'whcih')
# (1, 'weight')
# (1, 'week')
# (1, 'watt')
# (1, 'want')
# (1, 'waiting')
# (1, 've')
# (1, 'user')
# (1, 'used')
# (1, 'usage')
# (1, 'ur')
# (1, 'upto')
# (1, 'upgrade')
# (1, 'unlock')
# (1, 'unique')
# (1, 'ultra')
# (1, 'twice')
# (1, 'trust')
# (1, 'touch')
# (1, 'totally')
# (1, 'times')
# (1, 'time')
# (1, 'ticks')
# (1, 'thought')
# (1, 'thinking')
# (1, 'thanks')
# (1, 'tha')
# (1, 'temper')
# (1, 'tasks')
# (1, 'tasking')
# (1, 'talk')
# (1, 'taking')
# (1, 'taken')
# (1, 'take')
# (1, 'swear')
# (1, 'surfing')
# (1, 'support')
# (1, 'superfast')
# (1, 'superdisplay')
# (1, 'stunning')
# (1, 'started')
# (1, 'stabilized')
# (1, 'st')
# (1, 'speaker')
# (1, 'something')
# (1, 'someone')
# (1, 'solid')
# (1, 'software')
# (1, 'snapdragon')
# (1, 'smothness')
# (1, 'smart')
# (1, 'skeptical')
# (1, 'single')
# (1, 'similar')
# (1, 'significant')
# (1, 'side')
# (1, 'short')
# (1, 'sharper')
# (1, 'sharp')
# (1, 'selfies')
# (1, 'selfie')
# (1, 'see')
# (1, 'second')
# (1, 'scans')
# (1, 'scanner')
# (1, 'saying')
# (1, 'sare')
# (1, 'safe')
# (1, 'running')
# (1, 'run')
# (1, 'rs')
# (1, 'rounder')
# (1, 'rocks')
# (1, 'reviewing')
# (1, 'returning')
# (1, 'return')
# (1, 'results')
# (1, 'rest')
# (1, 'responsive')
# (1, 'replace')
# (1, 'remarkable')
# (1, 'reliable')
# (1, 'regards')
# (1, 'recording')
# (1, 'recent')
# (1, 'received')
# (1, 'rear')
# (1, 'qualities')
# (1, 'quad')
# (1, 'purchased')
# (1, 'pubg')
# (1, 'pros')
# (1, 'proper')
# (1, 'promising')
# (1, 'promised')
# (1, 'processing')
# (1, 'process')
# (1, 'problembut')
# (1, 'pricepremium')
# (1, 'pretty')
# (1, 'prefer')
# (1, 'powerful')
# (1, 'positive')
# (1, 'position')
# (1, 'popup')
# (1, 'pop')
# (1, 'poor')
# (1, 'policies')
# (1, 'playlow')
# (1, 'plastic')
# (1, 'photos')
# (1, 'photography')
# (1, 'photo')
# (1, 'perspective')
# (1, 'personally')
# (1, 'perfect')
# (1, 'people')
# (1, 'pec')
# (1, 'par')
# (1, 'packing')
# (1, 'package')
# (1, 'outstanding')
# (1, 'os')
# (1, 'oppo')
# (1, 'opinion')
# (1, 'okscreen')
# (1, 'okey')
# (1, 'nyc')
# (1, 'notch')
# (1, 'normal')
# (1, 'nikal')
# (1, 'night')
# (1, 'net')
# (1, 'negative')
# (1, 'need')
# (1, 'na')
# (1, 'multitasking')
# (1, 'multi')
# (1, 'moreover')
# (1, 'moneythanks')
# (1, 'money')
# (1, 'mobiles')
# (1, 'minute')
# (1, 'mins')
# (1, 'mind')
# (1, 'mid')
# (1, 'mega')
# (1, 'mark')
# (1, 'maker')
# (1, 'mah')
# (1, 'macro')
# (1, 'machine')
# (1, 'low')
# (1, 'loved')
# (1, 'loose')
# (1, 'll')
# (1, 'lite')
# (1, 'lighting')
# (1, 'light')
# (1, 'left')
# (1, 'lcd')
# (1, 'lacking')
# (1, 'know')
# (1, 'kirin')
# (1, 'kind')
# (1, 'karein')
# (1, 'issues')
# (1, 'isnot')
# (1, 'intensive')
# (1, 'insanely')
# (1, 'inr')
# (1, 'indoors')
# (1, 'incoming')
# (1, 'incase')
# (1, 'improvement')
# (1, 'improve')
# (1, 'immediately')
# (1, 'iffy')
# (1, 'huwaie')
# (1, 'however')
# (1, 'honour')
# (1, 'honorwhen')
# (1, 'honest')
# (1, 'holding')
# (1, 'hold')
# (1, 'ho')
# (1, 'high')
# (1, 'helped')
# (1, 'height')
# (1, 'heavy')
# (1, 'heating')
# (1, 'hdr')
# (1, 'havent')
# (1, 'hasn')
# (1, 'handling')
# (1, 'handles')
# (1, 'handle')
# (1, 'greatuptohdr')
# (1, 'grate')
# (1, 'grafics')
# (1, 'got')
# (1, 'google')
# (1, 'god')
# (1, 'glasscons')
# (1, 'giving')
# (1, 'give')
# (1, 'gett')
# (1, 'gets')
# (1, 'generation')
# (1, 'general')
# (1, 'gcam')
# (1, 'fully')
# (1, 'friends')
# (1, 'fream')
# (1, 'frame')
# (1, 'fr')
# (1, 'fps')
# (1, 'focussing')
# (1, 'fixed')
# (1, 'fits')
# (1, 'fingerprints')
# (1, 'fine')
# (1, 'final')
# (1, 'filter')
# (1, 'film')
# (1, 'fell')
# (1, 'feet')
# (1, 'faster')
# (1, 'facing')
# (1, 'face')
# (1, 'extreme')
# (1, 'excellenti')
# (1, 'excellant')
# (1, 'especially')
# (1, 'equal')
# (1, 'edges')
# (1, 'drops')
# (1, 'dropafter')
# (1, 'dream')
# (1, 'drain')
# (1, 'doubt')
# (1, 'disturb')
# (1, 'displays')
# (1, 'discount')
# (1, 'disappointment')
# (1, 'different')
# (1, 'didn')
# (1, 'diamond')
# (1, 'detected')
# (1, 'design')
# (1, 'deserves')
# (1, 'deal')
# (1, 'dark')
# (1, 'daily')
# (1, 'crisp')
# (1, 'crashing')
# (1, 'course')
# (1, 'couple')
# (1, 'cost')
# (1, 'convenient')
# (1, 'connection')
# (1, 'compared')
# (1, 'comparable')
# (1, 'compact')
# (1, 'comments')
# (1, 'comfortable')
# (1, 'color')
# (1, 'chinese')
# (1, 'charger')
# (1, 'charged')
# (1, 'changed')
# (1, 'cc')
# (1, 'cause')
# (1, 'cases')
# (1, 'capture')
# (1, 'cant')
# (1, 'cameras')
# (1, 'cam')
# (1, 'call')
# (1, 'bund')
# (1, 'bulk')
# (1, 'built')
# (1, 'build')
# (1, 'bughet')
# (1, 'broke')
# (1, 'bright')
# (1, 'breaker')
# (1, 'brands')
# (1, 'brand')
# (1, 'boxes')
# (1, 'box')
# (1, 'bought')
# (1, 'blur')
# (1, 'bit')
# (1, 'biglighting')
# (1, 'big')
# (1, 'believe')
# (1, 'befikra')
# (1, 'beat')
# (1, 'beast')
# (1, 'based')
# (1, 'bad')
# (1, 'backup')
# (1, 'back')
# (1, 'available')
# (1, 'attached')
# (1, 'asus')
# (1, 'aram')
# (1, 'apple')
# (1, 'appear')
# (1, 'angle')
# (1, 'amazonvalue')
# (1, 'alslo')
# (1, 'ahead')
# (1, 'ago')
# (1, 'actually')
# (1, 'activities')
# (1, 'according')
# (1, 'absolute')
# (1, 'aankh')

# %%
pwd
# Out:
# 'C:\\Users\\V Sudheer Kumar'

# %%
# WordCloud can be performed on the string inputs. That is the reason we have combined
# entire reviews into single paragraph
# Simple word cloud

# %%
wordcloud_ip = WordCloud(
                background_color='black',
                width=1800,
                height=1400
                ).generate(ip_rev_string)

# %%
plt.imshow(wordcloud_ip)
fig=plt.figure(figsize=(20,10),dpi=300)
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
# positive words # Choose the path for +ve words stored in system
with open("C:\\Users\\V Sudheer Kumar\\Documents\\poswords.txt","r") as pos:
    poswords = pos.read().split("\n")

# %%
poswords = poswords[36:]

# %%
# negative words # Choose the path for -ve words stored in system
with open("C:\\Users\\V Sudheer Kumar\\Documents\\negwords.txt","r") as neg:
    negwords = neg.read().split("\n")

# %%
negwords = negwords[37:]

# %%
# negative word cloud
# Choosing the only words which are present in negwords
ip_neg_in_neg = " ".join([w for w in ip_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                      ).generate(ip_neg_in_neg)

# %%
plt.figure(1)
plt.imshow(wordcloud_neg_in_neg)

# %%
# positive word cloud
# Choosing the only words which are present in poswords
ip_pos_in_pos = " ".join([w for w in ip_reviews_words if w in poswords])

wordcloud_pos_in_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                      ).generate(ip_pos_in_pos)

# %%
plt.figure(2)
plt.imshow(wordcloud_pos_in_pos)

# %%
# With white background

# %%
# negative word cloud
# Choosing the only words which are present in negwords
ip_neg_in_neg = " ".join([w for w in ip_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='white',
                      width=1800,
                      height=1400
                      ).generate(ip_neg_in_neg)

# %%
plt.figure(1)
plt.imshow(wordcloud_neg_in_neg)

# %%
# positive word cloud
# Choosing the only words which are present in poswords
ip_pos_in_pos = " ".join([w for w in ip_reviews_words if w in poswords])

wordcloud_pos_in_pos = WordCloud(
                      background_color='white',
                      width=1800,
                      height=1400
                      ).generate(ip_pos_in_pos)

# %%
plt.figure(2)
plt.imshow(wordcloud_pos_in_pos)
