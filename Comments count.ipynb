# %%
a = open('comments.txt')
b= a.read()
d= b.split()
for i in d:
    e= d.count(i)
    print(i,'=',e)
# Out:
# My = 1
# usual = 1
# size = 5
# is = 12
# a = 13
# 40 = 1
# so = 4
# I = 11
# ordered = 2
# the = 14
# L = 2
# size = 5
# as = 2
# suggested. = 1
# It = 2
# feels = 2
# a = 13
# little = 2
# too = 2
# big. = 1
# In = 1
# the = 14
# size = 5
# chart, = 1
# M = 3
# is = 12
# listed = 1
# at = 2
# 36-38 = 1
# so = 4
# I = 11
# assumed = 1
# it = 6
# would = 1
# be = 1
# a = 13
# somewhat = 1
# small. = 1
# The = 3
# fabric = 3
# is = 12
# comfortable = 3
# and = 7
# it = 6
# feels = 2
# like = 5
# I = 11
# could = 1
# wear = 3
# it = 6
# all = 1
# day = 2
# and = 7
# night. = 1
# Comment| = 8
# 11 = 2
# people = 4
# found = 8
# this = 21
# helpful. = 8
# Was = 8
# this = 21
# review = 10
# helpful = 9
# to = 13
# you? = 9
# Yes = 9
# No = 9
# Report = 9
# abuse = 9
# 4.0 = 2
# out = 9
# of = 12
# 5 = 10
# starsJockey = 1
# has = 5
# always = 2
# been = 2
# good = 10
# to = 13
# me = 3
# BydebrajTOP = 1
# 1000 = 1
# REVIEWERon = 1
# 11 = 2
# February = 2
# 2017 = 5
# Colour: = 9
# ...
