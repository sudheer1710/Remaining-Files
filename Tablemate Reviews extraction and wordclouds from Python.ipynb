# %% [markdown]
# # Udemy Amazon Reviews extraction

# %%
import requests # Importing requests to extract content from a url

# %%
from bs4 import BeautifulSoup as bs
import re

# %%
import nltk
from nltk.corpus import stopwords

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# creating empty reviews list
tablemate_reviews=[]
#forest = ["the","king","of","jungle"]

# %%
# Data extraction - Amazon reviews extraction

# %%
for i in range(1,11):
    ip=[]
    url = "https://www.amazon.in/MULTI-TABLE-Proud-Holder-Stronger/product-reviews/B06Y63RX13/ref=cm_cr_getr_d_paging_btm_prev"
    if i==1:
        url = url+"_"+str(i)+"?ie=UTF8&reviewerType=all_reviews&pageNumber="+str(i)
    else:
        url = url+"_"+str(i)+"?ie=UTF8&reviewerType=all_reviews&pageNumber="+str(i)
    #print(url)
    response = requests.get(url)
    soup = bs(response.content, "html.parser")# creating soup object to iterate over the extracted content
    reviews = soup.findAll("span", attrs={"class","a-size-base review-text review-text-content"})# Extracting the content under specific 
    for i in range(len(reviews)):
        tablemate_reviews.append(reviews[i].text)
print(tablemate_reviews)# adding the reviews of one page to empty list which in future contai
# Out:
# ["\nI am using this since 3 months, colour is good  buy table got bent with use, don't buy for long term purpose\n", '\nVery poor product...I have wasted my money...They have no option to return this crap...Suggest you not to purchase if you are planning to use this table for your laptop...Once you assemble the table, it shakes a lot while typing on the laptop...Therefore you cannot depend on it...Obviously,  You cannot keep a machine of starting price Rs.30,000/- on a 14-1500 table....Simple logic....\n', "\nI have been using this table for five months.  I have two tables, one was imported of very less sturdy and second one this. This table is excellent. As name suggested, it very sturdy compared to other tables.However one suggestion to supplier,  once table was fallen down and one of the two rotating hinges attached to the table was broken. However i replaced it with GI fitting locally available.  This problem i didn't face with the foreign make, whose design is excellent.  I request to modify the design or include it in the spare list.\n", "\nThird grade and cheap marketing tactics!! Using made in India name! The product is TableMate's cheap ripoff but with expensive price! With just the name difference and hardly any improvements over it. The table wobbles way too much to use and I am returning the product.\n", "\nThe multi table that i just received is standing my expectations. The color is perfect blue like I ordered. It's sturdy not that light in weight and easy to assemble and light in carrying. Overall good product for purpose of food and reading and writing. Just got it. Yet to know for how long it will stay but I feel it will solve the purpose for a long.time\n", '\nDo not buy this product waste of money with in 11 days of purchase the plastic attachment is broken worst attachment technology is used\n', '\nI never recommend this seller, because they sent me a damaged product knowingly.Defects:The clip under the table is found broken, (they know it is broken, still they sent me with a spare clip, so that I can assemble this time).The blue paint has been gone some parts and scratches are there, giving feeling that this is used one.Positives:The "product" is good. My usage is mainly for laptop usage. For my laptop(15.6 inches), it gives enuf room(comfortable, ability to type without shaking, etc) to use, it hard to use a mouse along with it in the table though.Negatives: The surface doesn\'t have good grip to hold my lap from sliding down (but if the laptop bottom is good with gripped rubber, then may not be a problem)Thanks.\n', '\nQuite a useful table which I use for laptop in front of tv. However, the table is quite shaky with a bit of wobbly legs. The tray also bent to one side into a slight gradual incline. Nothing unusuable though and still holds laptops/ tablets well. However, the water easily accumulates to one corner and putting something like tea / coffee cup (full to the brim) would result in spillage to one side.\n', '\nI purchased this multi table from amazon last week absolutely no problem in setting up or using as described on product page. The multi table is strong enough to hold any laptop. Cup holder comes handy when working for long. The manufacturer could have provided bushes or grip for legs to place the table firmly on the floor. Over all this is a best product for the price and feature, I would definitely recommend for family and friends.\n', '\nThe table is not sturdy at all. I use a Think T460 and the table moves a lot when typing on laptop keyboard. Assembly not a big deal at all. But I dint find it promising at all.. Also you do NOT have the option to RETURN & REFUND. The only option is replacement !! The Seller - Arush Enterprises wrote a THANK YOU note that says " We are the manufacturer of this product & we tried very hard to make it best. But still no one is perfect in the world "- that was WOW !! - they have already surrendered so no further issues.. lol\n', '\nMy son has been using thi ...

# %%
tablemate_reviews
# Out:
# ["\nI am using this since 3 months, colour is good  buy table got bent with use, don't buy for long term purpose\n",
#  '\nVery poor product...I have wasted my money...They have no option to return this crap...Suggest you not to purchase if you are planning to use this table for your laptop...Once you assemble the table, it shakes a lot while typing on the laptop...Therefore you cannot depend on it...Obviously,  You cannot keep a machine of starting price Rs.30,000/- on a 14-1500 table....Simple logic....\n',
#  "\nI have been using this table for five months.  I have two tables, one was imported of very less sturdy and second one this. This table is excellent. As name suggested, it very sturdy compared to other tables.However one suggestion to supplier,  once table was fallen down and one of the two rotating hinges attached to the table was broken. However i replaced it with GI fitting locally available.  This problem i didn't face with the foreign make, whose design is excellent.  I request to modify the design or include it in the spare list.\n",
#  "\nThird grade and cheap marketing tactics!! Using made in India name! The product is TableMate's cheap ripoff but with expensive price! With just the name difference and hardly any improvements over it. The table wobbles way too much to use and I am returning the product.\n",
#  "\nThe multi table that i just received is standing my expectations. The color is perfect blue like I ordered. It's sturdy not that light in weight and easy to assemble and light in carrying. Overall good product for purpose of food and reading and writing. Just got it. Yet to know for how long it will stay but I feel it will solve the purpose for a long.time\n",
#  '\nDo not buy this product waste of money with in 11 days of purchase the plastic attachment is broken worst attachment technology is used\n',
#  '\nI never recommend this seller, because they sent me a damaged product knowingly.Defects:The clip under the table is found broken, (they know it is broken, still they sent me with a spare clip, so that I can assemble this time).The blue paint has been gone some parts and scratches are there, giving feeling that this is used one.Positives:The "product" is good. My usage is mainly for laptop usage. For my laptop(15.6 inches), it gives enuf room(comfortable, ability to type without shaking, etc) to use, it hard to use a mouse along with it in the table though.Negatives: The surface doesn\'t have good grip to hold my lap from sliding down (but if the laptop bottom is good with gripped rubber, then may not be a problem)Thanks.\n',
#  '\nQuite a useful table which I use for laptop in front of tv. However, the table is quite shaky with a bit of wobbly legs. The tray also bent to one side into a slight gradual incline. Nothing unusuable though and still holds laptops/ tablets well. However, the water easily accumulates to one corner and putting something like tea / coffee cup (full to the brim) would result in spillage to one side.\n',
#  '\nI purchased this multi table from amazon last week absolutely no problem in setting up or using as described on product page. The multi table is strong enough to hold any laptop. Cup holder comes handy when working for long. The manufacturer could have provided bushes or grip for legs to place the table firmly on the floor. Over all this is a best product for the price and feature, I would definitely recommend for family and friends.\n',
#  '\nThe table is not sturdy at all. I use a Think T460 and the table moves a lot when typing on laptop keyboard. Assembly not a big deal at all. But I dint find it promising at all.. Also you do NOT have the option to RETURN & REFUND. The only option is replacement !! The Seller - Arush Enterprises wrote a THANK YOU note that says " We are the manufacturer of this product & we tried very hard to make it best. But still no one is perfect in the world "- that was WOW !! - they have already surrendered so no further issues.. lol\n',
#  '\nMy son has been using this for a couple of months now. It can be used sitting on the bed or a proper chair. The product is user-friendly and not very complicated.  It can be adjusted to various height depending on where the person sits .\n',
#  '\nIt serves my purpose. Quality and flexibility is good enough.However the table is quite shaky for me. Probably the issue is with my floor. Will try to fix it.Delivery and packaging by Amazon is just amazing.\n',
#  '\nIntial impression was good, i have seen many other tablemates but this one quite good. And its body is built with good qualityDespite the negative commnets or ratings you can go for this product. It was valuble product to purchase.\n',
#  "\nYesterday 29.07.17 received two multi table. It's really worth for and in very good quality.It's strong.It's better than the tv product. It's better than the shop material.My niece's are very Happy..\n",
#  '\nJust after a month of use that too only with weight of a light corporate laptop, mouse and a small diary, table started bending in the middle slowly.Looks it is unable to take weight of hand while typing.I am sure I cannot use it for more than 2-3 months.\n',
#  '\nGood, strong, mobile, durable and does not takes much space. I have bee using it for eating, writing, working on laptop. Would have given 5 but for the price. It should have been around 200 Rs. cheaper.\n',
#  '\nChanges made as to fix table top to iron stand good. But it cannot be stashed to a corner as it cannot stand on its own with table top folded.\n',
#  '\nIts a good but only for laptop use. Easy to assemble and portable . Donr expect that it is capable of carrying heavy things. Cant keep more than 4 books on this. I purchased it today and i could see a lil bend ,but i think its not defect. And if i say its not worth of 1500rs.  Must take care of it.as its a fragile type.\n',
#  '\nNot much of use if you want a table for study purpose or something related to that  . It’s not steady and and it’s always shaking as the base support is weak. I was hoping that the table would be helpful for studies but since it was shaking always I didn’t like to use it.\n',
#  '\nArrived broken and scratched. The hinge type plastic connector that connects the table top and the table legs was broken. Unsure if it was done in shipping but it seems quite fragile\n',
#  "\nNice product. received before delivery date. appreciate amazon's service. quality/finishing of the table looks good and sturdy. cost is a bit high compared to its counterparts.if cost isnt an issue, i would recommend this.....\n",
#  '\n\xa0I can not assemble it since the bore size is smaller than the dia of the rod. Poor workmanship\n',
#  "\nProduct quality is good and ease to assemble but not much strongly holds.Feels uncomfortable while using, don't even fit for all the work because of its shaking problem.Overall, not much satisfied product and not worth for the money. Costly and not much good one.\n",
#  '\nProduct is okay. It can able to hold laptop however while typing, table is shaking like a roller coaster. Durability is very less compared to other table products. This is high in price. Better look for cheap one. This price is not at all worthy for this product.\n',
#  '\nIt is useful and at least 4 inches less broad. The lower base should be flat rather than tubular.\n',
#  "\nThe Product is according to the specifications shared.Only drawback which I'm seeing is that the table is progressively loosing its stability.For the price of the Product, you can easily go for a plastic table if you're looking not looking for mobility.\n",
#  '\nThe Table is good for reading but wobbles when we try to write something. But it is manageable.\n',
#  '\nNice product. There is a bit of shaking but all is fine. I use it sometimes as a laptop desk but it is mostly used like a dining table everyday and is fine after regular usage of little more than a year.\n',
#  "\nI didn't give one star because if we add pressure or keep our both hands with weight  I will break off its desk is not strong and glass keeper is also not strong\n",
#  '\nProduct is a good quality product and full fill all the details mentioned in the description. Value for money and durable product if used with care. Benefit for aged people where product is light and easy to use.\n',
#  '\nOk. Colour does not match with the indicated on\n',
#  '\nThe product is really a good.. it is indian made not china made.  its perfect and valuable.  its really fine material.I am happy with this product & suggest to buy it.\n',
#  "\n1) Excellent product for its cost2) Most convenient to carry around the room.3) Comfortable for all the ages as it's ease size adjustable.\n",
#  '\nThe study table is sturdy been using it for long... Quality is good .. Height is easily adjustable..Overall its a very good purchase..It is a multipurpose table..\n',
#  "\nGreat product. Just loved it. Morever product is brought from India's Shop Amazon. So i can blindly give a five star review to this item.\n",
#  '\nNice\n',
#  '\nThanks for quick delivery inspire of lock down. The product looks great\n',
#  '\nProduct is good....Quality is also good....I bought for 1500 but the price is too high for the quality...\n',
#  "\nIt's nice but the clamp is made of plastic which is broken when the table mate fell down in holding position\n",
#  '\nI was very apprehensive before purchasing this wondering what the quality will be like. The table is quite sturdy and the quality is good. It is value for money.\n',
#  "\nI thought its like original table mate, but it's not, it's duplicate, it's not perfect stable on ground, only for sitting position height, not for the other heights\n",
#  '\nShakes a lot. Not suitable for writing.Perfect for working with laptop/dining table.Can be used as study table to some extent.\n',
#  '\nStrong and StubbornVery good product\n',
#  '\nGood product using it for my laptop work at my home\n',
#  '\nThe product isn’t new, I guess it’s a used one which is sold to me again - have capture images of damages / scratches. This should have been described as refurbished and not new.\n',
#  '\ni am using it for over an year. I use this table to work on laptop. Very convenient.\n',
#  "\nQuite portable and decent enough to use regularly. But it is kinda overpriced. It could've been priced around 1100 rupees\n",
#  '\nWorth the money\n',
#  '\nNice product. Good quality.. Easy to assemble. I got for 1287..\n',
#  '\nSimply strong and best...\n']

# %%
# Data cleansing and Wordcloud

# %%
# writing reviews in a text file

# %%
with open("tablemate_reviews.txt","w",encoding='utf8') as output:
    output.write(str(tablemate_reviews))

# %%
# Joining all the reviews into single paragraph
ip_rev_string = " ".join(tablemate_reviews)

# %%
ip_rev_string
# Out:
# '\nI am using this since 3 months, colour is good  buy table got bent with use, don\'t buy for long term purpose\n \nVery poor product...I have wasted my money...They have no option to return this crap...Suggest you not to purchase if you are planning to use this table for your laptop...Once you assemble the table, it shakes a lot while typing on the laptop...Therefore you cannot depend on it...Obviously,  You cannot keep a machine of starting price Rs.30,000/- on a 14-1500 table....Simple logic....\n \nI have been using this table for five months.  I have two tables, one was imported of very less sturdy and second one this. This table is excellent. As name suggested, it very sturdy compared to other tables.However one suggestion to supplier,  once table was fallen down and one of the two rotating hinges attached to the table was broken. However i replaced it with GI fitting locally available.  This problem i didn\'t face with the foreign make, whose design is excellent.  I request to modify the design or include it in the spare list.\n \nThird grade and cheap marketing tactics!! Using made in India name! The product is TableMate\'s cheap ripoff but with expensive price! With just the name difference and hardly any improvements over it. The table wobbles way too much to use and I am returning the product.\n \nThe multi table that i just received is standing my expectations. The color is perfect blue like I ordered. It\'s sturdy not that light in weight and easy to assemble and light in carrying. Overall good product for purpose of food and reading and writing. Just got it. Yet to know for how long it will stay but I feel it will solve the purpose for a long.time\n \nDo not buy this product waste of money with in 11 days of purchase the plastic attachment is broken worst attachment technology is used\n \nI never recommend this seller, because they sent me a damaged product knowingly.Defects:The clip under the table is found broken, (they know it is broken, still they sent me with a spare clip, so that I can assemble this time).The blue paint has been gone some parts and scratches are there, giving feeling that this is used one.Positives:The "product" is good. My usage is mainly for laptop usage. For my laptop(15.6 inches), it gives enuf room(comfortable, ability to type without shaking, etc) to use, it hard to use a mouse along with it in the table though.Negatives: The surface doesn\'t have good grip to hold my lap from sliding down (but if the laptop bottom is good with gripped rubber, then may not be a problem)Thanks.\n \nQuite a useful table which I use for laptop in front of tv. However, the table is quite shaky with a bit of wobbly legs. The tray also bent to one side into a slight gradual incline. Nothing unusuable though and still holds laptops/ tablets well. However, the water easily accumulates to one corner and putting something like tea / coffee cup (full to the brim) would result in spillage to one side.\n \nI purchased this multi table from amazon last week absolutely no problem in setting up or using as described on product page. The multi table is strong enough to hold any laptop. Cup holder comes handy when working for long. The manufacturer could have provided bushes or grip for legs to place the table firmly on the floor. Over all this is a best product for the price and feature, I would definitely recommend for family and friends.\n \nThe table is not sturdy at all. I use a Think T460 and the table moves a lot when typing on laptop keyboard. Assembly not a big deal at all. But I dint find it promising at all.. Also you do NOT have the option to RETURN & REFUND. The only option is replacement !! The Seller - Arush Enterprises wrote a THANK YOU note that says " We are the manufacturer of this product & we tried very hard to make it best. But still no one is perfect in the world "- that was WOW !! - they have already surrendered so no further issues.. lol\n \nMy son has been using this for a couple of months no ...

# %%
# Removing unwanted symbols incase if exists
ip_rev_string = re.sub("[^A-Za-z" "]+"," ",ip_rev_string).lower()
ip_rev_string = re.sub("[0-9" "]+"," ",ip_rev_string)

# %%
ip_rev_string
# Out:
# ' i am using this since months colour is good buy table got bent with use don t buy for long term purpose very poor product i have wasted my money they have no option to return this crap suggest you not to purchase if you are planning to use this table for your laptop once you assemble the table it shakes a lot while typing on the laptop therefore you cannot depend on it obviously you cannot keep a machine of starting price rs on a table simple logic i have been using this table for five months i have two tables one was imported of very less sturdy and second one this this table is excellent as name suggested it very sturdy compared to other tables however one suggestion to supplier once table was fallen down and one of the two rotating hinges attached to the table was broken however i replaced it with gi fitting locally available this problem i didn t face with the foreign make whose design is excellent i request to modify the design or include it in the spare list third grade and cheap marketing tactics using made in india name the product is tablemate s cheap ripoff but with expensive price with just the name difference and hardly any improvements over it the table wobbles way too much to use and i am returning the product the multi table that i just received is standing my expectations the color is perfect blue like i ordered it s sturdy not that light in weight and easy to assemble and light in carrying overall good product for purpose of food and reading and writing just got it yet to know for how long it will stay but i feel it will solve the purpose for a long time do not buy this product waste of money with in days of purchase the plastic attachment is broken worst attachment technology is used i never recommend this seller because they sent me a damaged product knowingly defects the clip under the table is found broken they know it is broken still they sent me with a spare clip so that i can assemble this time the blue paint has been gone some parts and scratches are there giving feeling that this is used one positives the product is good my usage is mainly for laptop usage for my laptop inches it gives enuf room comfortable ability to type without shaking etc to use it hard to use a mouse along with it in the table though negatives the surface doesn t have good grip to hold my lap from sliding down but if the laptop bottom is good with gripped rubber then may not be a problem thanks quite a useful table which i use for laptop in front of tv however the table is quite shaky with a bit of wobbly legs the tray also bent to one side into a slight gradual incline nothing unusuable though and still holds laptops tablets well however the water easily accumulates to one corner and putting something like tea coffee cup full to the brim would result in spillage to one side i purchased this multi table from amazon last week absolutely no problem in setting up or using as described on product page the multi table is strong enough to hold any laptop cup holder comes handy when working for long the manufacturer could have provided bushes or grip for legs to place the table firmly on the floor over all this is a best product for the price and feature i would definitely recommend for family and friends the table is not sturdy at all i use a think t and the table moves a lot when typing on laptop keyboard assembly not a big deal at all but i dint find it promising at all also you do not have the option to return refund the only option is replacement the seller arush enterprises wrote a thank you note that says we are the manufacturer of this product we tried very hard to make it best but still no one is perfect in the world that was wow they have already surrendered so no further issues lol my son has been using this for a couple of months now it can be used sitting on the bed or a proper chair the product is user friendly and not very complicated it can be adjusted to various height depending on where the person sits it serves my p ...

# %%
# words that contained in iphone 8 plus reviews
ip_reviews_words = ip_rev_string.split(" ")

# %%
ip_reviews_words
# Out:
# ['',
#  'i',
#  'am',
#  'using',
#  'this',
#  'since',
#  'months',
#  'colour',
#  'is',
#  'good',
#  'buy',
#  'table',
#  'got',
#  'bent',
#  'with',
#  'use',
#  'don',
#  't',
#  'buy',
#  'for',
#  'long',
#  'term',
#  'purpose',
#  'very',
#  'poor',
#  'product',
#  'i',
#  'have',
#  'wasted',
#  'my',
#  'money',
#  'they',
#  'have',
#  'no',
#  'option',
#  'to',
#  'return',
#  'this',
#  'crap',
#  'suggest',
#  'you',
#  'not',
#  'to',
#  'purchase',
#  'if',
#  'you',
#  'are',
#  'planning',
#  'to',
#  'use',
#  'this',
#  'table',
#  'for',
#  'your',
#  'laptop',
#  'once',
#  'you',
#  'assemble',
#  'the',
#  'table',
#  'it',
#  'shakes',
#  'a',
#  'lot',
#  'while',
#  'typing',
#  'on',
#  'the',
#  'laptop',
#  'therefore',
#  'you',
#  'cannot',
#  'depend',
#  'on',
#  'it',
#  'obviously',
#  'you',
#  'cannot',
#  'keep',
#  'a',
#  'machine',
#  'of',
#  'starting',
#  'price',
#  'rs',
#  'on',
#  'a',
#  'table',
#  'simple',
#  'logic',
#  'i',
#  'have',
#  'been',
#  'using',
#  'this',
#  'table',
#  'for',
#  'five',
#  'months',
#  'i',
#  'have',
#  'two',
#  'tables',
#  'one',
#  'was',
#  'imported',
#  'of',
#  'very',
#  'less',
#  'sturdy',
#  'and',
#  'second',
#  'one',
#  'this',
#  'this',
#  'table',
#  'is',
#  'excellent',
#  'as',
#  'name',
#  'suggested',
#  'it',
#  'very',
#  'sturdy',
#  'compared',
#  'to',
#  'other',
#  'tables',
#  'however',
#  'one',
#  'suggestion',
#  'to',
#  'supplier',
#  'once',
#  'table',
#  'was',
#  'fallen',
#  'down',
#  'and',
#  'one',
#  'of',
#  'the',
#  'two',
#  'rotating',
#  'hinges',
#  'attached',
#  'to',
#  'the',
#  'table',
#  'was',
#  'broken',
#  'however',
#  'i',
#  'replaced',
#  'it',
#  'with',
#  'gi',
#  'fitting',
#  'locally',
#  'available',
#  'this',
#  'problem',
#  'i',
#  'didn',
#  't',
#  'face',
#  'with',
#  'the',
#  'foreign',
#  'make',
#  'whose',
#  'design',
#  'is',
#  'excellent',
#  'i',
#  'request',
#  'to',
#  'modify',
#  'the',
#  'design',
#  'or',
#  'include',
#  'it',
#  'in',
#  'the',
#  'spare',
#  'list',
#  'third',
#  'grade',
#  'and',
#  'cheap',
#  'marketing',
#  'tactics',
#  'using',
#  'made',
#  'in',
#  'india',
#  'name',
#  'the',
#  'product',
#  'is',
#  'tablemate',
#  's',
#  'cheap',
#  'ripoff',
#  'but',
#  'with',
#  'expensive',
#  'price',
#  'with',
#  'just',
#  'the',
#  'name',
#  'difference',
#  'and',
#  'hardly',
#  'any',
#  'improvements',
#  'over',
#  'it',
#  'the',
#  'table',
#  'wobbles',
#  'way',
#  'too',
#  'much',
#  'to',
#  'use',
#  'and',
#  'i',
#  'am',
#  'returning',
#  'the',
#  'product',
#  'the',
#  'multi',
#  'table',
#  'that',
#  'i',
#  'just',
#  'received',
#  'is',
#  'standing',
#  'my',
#  'expectations',
#  'the',
#  'color',
#  'is',
#  'perfect',
#  'blue',
#  'like',
#  'i',
#  'ordered',
#  'it',
#  's',
#  'sturdy',
#  'not',
#  'that',
#  'light',
#  'in',
#  'weight',
#  'and',
#  'easy',
#  'to',
#  'assemble',
#  'and',
#  'light',
#  'in',
#  'carrying',
#  'overall',
#  'good',
#  'product',
#  'for',
#  'purpose',
#  'of',
#  'food',
#  'and',
#  'reading',
#  'and',
#  'writing',
#  'just',
#  'got',
#  'it',
#  'yet',
#  'to',
#  'know',
#  'for',
#  'how',
#  'long',
#  'it',
#  'will',
#  'stay',
#  'but',
#  'i',
#  'feel',
#  'it',
#  'will',
#  'solve',
#  'the',
#  'purpose',
#  'for',
#  'a',
#  'long',
#  'time',
#  'do',
#  'not',
#  'buy',
#  'this',
#  'product',
#  'waste',
#  'of',
#  'money',
#  'with',
#  'in',
#  'days',
#  'of',
#  'purchase',
#  'the',
#  'plastic',
#  'attachment',
#  'is',
#  'broken',
#  'worst',
#  'attachment',
#  'technology',
#  'is',
#  'used',
#  'i',
#  'never',
#  'recommend',
#  'this',
#  'seller',
#  'because',
#  'they',
#  'sent',
#  'me',
#  'a',
#  'damaged',
#  'product',
#  'knowingly',
#  'defects',
#  'the',
#  'clip',
#  'under',
#  'the',
#  'table',
#  'is',
#  'found',
#  'broken',
#  'they',
#  'know',
#  'it',
#  'is',
#  'broken',
#  'still',
#  'they',
#  'sent',
#  'me',
#  'with',
#  'a',
#  'spare',
#  'clip',
#  'so',
#  'that',
#  'i',
#  'can',
#  'assemble',
#  'this',
#  'time',
#  'the',
#  'blue',
#  'paint',
#  'has',
#  'been',
#  'gone',
#  'some',
#  'parts',
#  'and',
#  'scratches',
#  'are',
#  'there',
#  'giving',
#  'feeling',
#  'that',
#  'this',
#  'is',
#  'used',
#  'one',
#  'positives',
#  'the',
#  'product',
#  'is',
#  'good',
#  'my',
#  'usage',
#  'is',
#  'mainly',
#  'for',
#  'laptop',
#  'usage',
#  'for',
#  'my',
#  'laptop',
#  'inches',
#  'it',
#  'gives',
#  'enuf',
#  'room',
#  'comfortable',
#  'ability',
#  'to',
#  'type',
#  'without',
#  'shaking',
#  'etc',
#  'to',
#  'use',
#  'it',
#  'hard',
#  'to',
#  'use',
#  'a',
#  'mouse',
#  'along',
#  'with',
#  'it',
#  'in',
#  'the',
#  'table',
#  'though',
#  'negatives',
#  'the',
#  'surface',
#  'doesn',
#  't',
#  'have',
#  'good',
#  'grip',
#  'to',
#  'hold',
#  'my',
#  'lap',
#  'from',
#  'sliding',
#  'down',
#  'but',
#  'if',
#  'the',
#  'laptop',
#  'bottom',
#  'is',
#  'good',
#  'with',
#  'gripped',
#  'rubber',
#  'then',
#  'may',
#  'not',
#  'be',
#  'a',
#  'problem',
#  'thanks',
#  'quite',
#  'a',
#  'useful',
#  'table',
#  'which',
#  'i',
#  'use',
#  'for',
#  'laptop',
#  'in',
#  'front',
#  'of',
#  'tv',
#  'however',
#  'the',
#  'table',
#  'is',
#  'quite',
#  'shaky',
#  'with',
#  'a',
#  'bit',
#  'of',
#  'wobbly',
#  'legs',
#  'the',
#  'tray',
#  'also',
#  'bent',
#  'to',
#  'one',
#  'side',
#  'into',
#  'a',
#  'slight',
#  'gradual',
#  'incline',
#  'nothing',
#  'unusuable',
#  'though',
#  'and',
#  'still',
#  'holds',
#  'laptops',
#  'tablets',
#  'well',
#  'however',
#  'the',
#  'water',
#  'easily',
#  'accumulates',
#  'to',
#  'one',
#  'corner',
#  'and',
#  'putting',
#  'something',
#  'like',
#  'tea',
#  'coffee',
#  'cup',
#  'full',
#  'to',
#  'the',
#  'brim',
#  'would',
#  'result',
#  'in',
#  'spillage',
#  'to',
#  'one',
#  'side',
#  'i',
#  'purchased',
#  'this',
#  'multi',
#  'table',
#  'from',
#  'amazon',
#  'last',
#  'week',
#  'absolutely',
#  'no',
#  'problem',
#  'in',
#  'setting',
#  'up',
#  'or',
#  'using',
#  'as',
#  'described',
#  'on',
#  'product',
#  'page',
#  'the',
#  'multi',
#  'table',
#  'is',
#  'strong',
#  'enough',
#  'to',
#  'hold',
#  'any',
#  'laptop',
#  'cup',
#  'holder',
#  'comes',
#  'handy',
#  'when',
#  'working',
#  'for',
#  'long',
#  'the',
#  'manufacturer',
#  'could',
#  'have',
#  'provided',
#  'bushes',
#  'or',
#  'grip',
#  'for',
#  'legs',
#  'to',
#  'place',
#  'the',
#  'table',
#  'firmly',
#  'on',
#  'the',
#  'floor',
#  'over',
#  'all',
#  'this',
#  'is',
#  'a',
#  'best',
#  'product',
#  'for',
#  'the',
#  'price',
#  'and',
#  'feature',
#  'i',
#  'would',
#  'definitely',
#  'recommend',
#  'for',
#  'family',
#  'and',
#  'friends',
#  'the',
#  'table',
#  'is',
#  'not',
#  'sturdy',
#  'at',
#  'all',
#  'i',
#  'use',
#  'a',
#  'think',
#  't',
#  'and',
#  'the',
#  'table',
#  'moves',
#  'a',
#  'lot',
#  'when',
#  'typing',
#  'on',
#  'laptop',
#  'keyboard',
#  'assembly',
#  'not',
#  'a',
#  'big',
#  'deal',
#  'at',
#  'all',
#  'but',
#  'i',
#  'dint',
#  'find',
#  'it',
#  'promising',
#  'at',
#  'all',
#  'also',
#  'you',
#  'do',
#  'not',
#  'have',
#  'the',
#  'option',
#  'to',
#  'return',
#  'refund',
#  'the',
#  'only',
#  'option',
#  'is',
#  'replacement',
#  'the',
#  'seller',
#  'arush',
#  'enterprises',
#  'wrote',
#  'a',
#  'thank',
#  'you',
#  'note',
#  'that',
#  'says',
#  'we',
#  'are',
#  'the',
#  'manufacturer',
#  'of',
#  'this',
#  'product',
#  'we',
#  'tried',
#  'very',
#  'hard',
#  'to',
#  'make',
#  'it',
#  'best',
#  'but',
#  'still',
#  'no',
#  'one',
#  'is',
#  'perfect',
#  'in',
#  'the',
#  'world',
#  'that',
#  'was',
#  'wow',
#  'they',
#  'have',
#  'already',
#  'surrendered',
#  'so',
#  'no',
#  'further',
#  'issues',
#  'lol',
#  'my',
#  'son',
#  'has',
#  'been',
#  'using',
#  'this',
#  'for',
#  'a',
#  'couple',
#  'of',
#  'months',
#  'now',
#  'it',
#  'can',
#  'be',
#  'used',
#  'sitting',
#  'on',
#  'the',
#  'bed',
#  'or',
#  'a',
#  'proper',
#  'chair',
#  'the',
#  'product',
#  'is',
#  'user',
#  'friendly',
#  'and',
#  'not',
#  'very',
#  'complicated',
#  'it',
#  'can',
#  'be',
#  'adjusted',
#  'to',
#  'various',
#  'height',
#  'depending',
#  'on',
#  'where',
#  'the',
#  'person',
#  'sits',
#  'it',
#  'serves',
#  'my',
#  'purpose',
#  'quality',
#  'and',
#  'flexibility',
#  'is',
#  'good',
#  'enough',
#  'however',
#  'the',
#  'table',
#  'is',
#  'quite',
#  'shaky',
#  'for',
#  'me',
#  'probably',
#  'the',
#  'issue',
#  'is',
#  'with',
#  'my',
#  'floor',
#  'will',
#  'try',
#  'to',
#  'fix',
#  'it',
#  'delivery',
#  'and',
#  'packaging',
#  'by',
#  'amazon',
#  'is',
#  'just',
#  'amazing',
#  'intial',
#  'impression',
#  'was',
#  'good',
#  'i',
#  'have',
#  'seen',
#  'many',
#  'other',
#  'tablemates',
#  'but',
#  'this',
#  'one',
#  'quite',
#  'good',
#  'and',
#  'its',
#  'body',
#  'is',
#  'built',
#  'with',
#  'good',
#  'qualitydespite',
#  'the',
#  'negative',
#  'commnets',
#  'or',
#  'ratings',
#  'you',
#  'can',
#  'go',
#  'for',
#  'this',
#  'product',
#  'it',
#  'was',
#  'valuble',
#  'product',
#  'to',
#  'purchase',
#  'yesterday',
#  'received',
#  'two',
#  'multi',
#  'table',
#  'it',
#  's',
#  'really',
#  'worth',
#  'for',
#  'and',
#  'in',
#  'very',
#  'good',
#  'quality',
#  'it',
#  's',
#  'strong',
#  'it',
#  's',
#  'better',
#  'than',
#  'the',
#  'tv',
#  'product',
#  'it',
#  's',
#  'better',
#  'than',
#  'the',
#  'shop',
#  'material',
#  'my',
#  'niece',
#  's',
#  'are',
#  'very',
#  'happy',
#  'just',
#  'after',
#  'a',
#  'month',
#  'of',
#  'use',
#  'that',
#  'too',
#  'only',
#  'with',
#  'weight',
#  'of',
#  'a',
#  'light',
#  'corporate',
#  'laptop',
#  'mouse',
#  'and',
#  'a',
#  'small',
#  'diary',
#  'table',
#  'started',
#  'bending',
#  'in',
#  'the',
#  'middle',
#  'slowly',
#  'looks',
#  'it',
#  'is',
#  'unable',
#  'to',
#  'take',
#  'weight',
#  'of',
#  'hand',
#  'while',
#  'typing',
#  'i',
#  'am',
#  'sure',
#  'i',
#  'cannot',
#  'use',
#  'it',
#  'for',
#  'more',
#  'than',
#  'months',
#  'good',
#  'strong',
#  'mobile',
#  'durable',
#  'and',
#  'does',
#  'not',
#  'takes',
#  'much',
#  'space',
#  'i',
#  'have',
#  'bee',
#  'using',
#  'it',
#  'for',
#  'eating',
#  'writing',
#  'working',
#  'on',
#  'laptop',
#  'would',
#  'have',
#  'given',
#  'but',
#  'for',
#  'the',
#  'price',
#  'it',
#  'should',
#  'have',
#  'been',
#  'around',
#  'rs',
#  'cheaper',
#  'changes',
#  'made',
#  'as',
#  'to',
#  'fix',
#  'table',
#  'top',
#  'to',
#  'iron',
#  'stand',
#  'good',
#  'but',
#  'it',
#  'cannot',
#  'be',
#  'stashed',
#  'to',
#  'a',
#  'corner',
#  'as',
#  'it',
#  'cannot',
#  'stand',
#  'on',
#  'its',
#  'own',
#  'with',
#  'table',
#  'top',
#  'folded',
#  'its',
#  'a',
#  'good',
#  'but',
#  'only',
#  'for',
#  'laptop',
#  'use',
#  'easy',
#  'to',
#  'assemble',
#  ...]

# %%
# stop_words = stopwords.words('english') can use this command if nltk loaded

# %%
with open("C:\\Users\\V Sudheer Kumar\\stopwords_en.txt") as sw:
    stopwords = sw.read()

# %%
stopwords = stopwords.split("\n")

# %%
temp = ["this","is","awsome","Data","Science"]
[i for i in temp if i not in "is"]
# Out:
# ['this', 'awsome', 'Data', 'Science']

# %%
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'would',
#  'should',
#  'could',
#  'ought',
#  "i'm",
#  "you're",
#  "he's",
#  "she's",
#  "it's",
#  "we're",
#  "they're",
#  "i've",
#  "you've",
#  "we've",
#  "they've",
#  "i'd",
#  "you'd",
#  "he'd",
#  "she'd",
#  "we'd",
#  "they'd",
#  "i'll",
#  "you'll",
#  "he'll",
#  "she'll",
#  "we'll",
#  "they'll",
#  "isn't",
#  "aren't",
#  "wasn't",
#  "weren't",
#  "hasn't",
#  "haven't",
#  "hadn't",
#  "doesn't",
#  "don't",
#  "didn't",
#  "won't",
#  "wouldn't",
#  "shan't",
#  "shouldn't",
#  "can't",
#  'cannot',
#  "couldn't",
#  "mustn't",
#  "let's",
#  "that's",
#  "who's",
#  "what's",
#  "here's",
#  "there's",
#  "when's",
#  "where's",
#  "why's",
#  "how's",
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  '']

# %%
ip_reviews_words = [w for w in ip_reviews_words if not w in stopwords]

# %%
# Joining all the reviews into single paragraph
ip_rev_string = " ".join(ip_reviews_words)

# %%
ip_rev_string
# Out:
# 'using since months colour good buy table got bent use don t buy long term purpose poor product wasted money option return crap suggest purchase planning use table laptop assemble table shakes lot typing laptop therefore depend obviously keep machine starting price rs table simple logic using table five months two tables one imported less sturdy second one table excellent name suggested sturdy compared tables however one suggestion supplier table fallen one two rotating hinges attached table broken however replaced gi fitting locally available problem didn t face foreign make whose design excellent request modify design include spare list third grade cheap marketing tactics using made india name product tablemate s cheap ripoff expensive price just name difference hardly improvements table wobbles way much use returning product multi table just received standing expectations color perfect blue like ordered s sturdy light weight easy assemble light carrying overall good product purpose food reading writing just got yet know long will stay feel will solve purpose long time buy product waste money days purchase plastic attachment broken worst attachment technology used never recommend seller sent damaged product knowingly defects clip table found broken know broken still sent spare clip can assemble time blue paint gone parts scratches giving feeling used one positives product good usage mainly laptop usage laptop inches gives enuf room comfortable ability type without shaking etc use hard use mouse along table though negatives surface doesn t good grip hold lap sliding laptop bottom good gripped rubber may problem thanks quite useful table use laptop front tv however table quite shaky bit wobbly legs tray also bent one side slight gradual incline nothing unusuable though still holds laptops tablets well however water easily accumulates one corner putting something like tea coffee cup full brim result spillage one side purchased multi table amazon last week absolutely problem setting using described product page multi table strong enough hold laptop cup holder comes handy working long manufacturer provided bushes grip legs place table firmly floor best product price feature definitely recommend family friends table sturdy use think t table moves lot typing laptop keyboard assembly big deal dint find promising also option return refund option replacement seller arush enterprises wrote thank note says manufacturer product tried hard make best still one perfect world wow already surrendered issues lol son using couple months now can used sitting bed proper chair product user friendly complicated can adjusted various height depending person sits serves purpose quality flexibility good enough however table quite shaky probably issue floor will try fix delivery packaging amazon just amazing intial impression good seen many tablemates one quite good body built good qualitydespite negative commnets ratings can go product valuble product purchase yesterday received two multi table s really worth good quality s strong s better tv product s better shop material niece s happy just month use weight light corporate laptop mouse small diary table started bending middle slowly looks unable take weight hand typing sure use months good strong mobile durable takes much space bee using eating writing working laptop given price around rs cheaper changes made fix table top iron stand good stashed corner stand table top folded good laptop use easy assemble portable donr expect capable carrying heavy things cant keep books purchased today see lil bend think defect say worth rs must take care fragile type much use want table study purpose something related s steady s always shaking base support weak hoping table helpful studies since shaking always didn t like use arrived broken scratched hinge type plastic connector connects table top table legs broken unsure done shipping seems quite fragile nice product received delivery date appreciate amazon s servi ...

# %%
# Python3 code to find frequency of each word 

def wordListToFreqDict(wordlist):
    wordfreq = [wordlist.count(p) for p in wordlist]
    return dict(list(zip(wordlist,wordfreq)))

def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

str_list = ip_rev_string.split()

dictionary = wordListToFreqDict(str_list)
sorteddict = sortFreqDict(dictionary)

for s in sorteddict: print(str(s))
# Out:
# (43, 'table')
# (37, 'product')
# (27, 'good')
# (17, 's')
# (16, 'use')
# (16, 'laptop')
# (14, 'one')
# (11, 'quality')
# (10, 'using')
# (9, 'can')
# (8, 't')
# (8, 'price')
# (7, 'used')
# (7, 'sturdy')
# (7, 'strong')
# (7, 'quite')
# (7, 'like')
# (7, 'broken')
# (7, 'assemble')
# (6, 'shaking')
# (6, 'much')
# (6, 'money')
# (6, 'just')
# (6, 'however')
# (5, 'will')
# (5, 'purpose')
# (5, 'perfect')
# (5, 'nice')
# (5, 'made')
# (5, 'long')
# (4, 'worth')
# (4, 'weight')
# (4, 'typing')
# (4, 'purchase')
# (4, 'problem')
# (4, 'plastic')
# (4, 'multi')
# (4, 'months')
# (4, 'light')
# (4, 'easy')
# (4, 'buy')
# (4, 'amazon')
# (4, 'also')
# (3, 'writing')
# (3, 'working')
# (3, 'work')
# (3, 'usage')
# (3, 'type')
# (3, 'two')
# (3, 'top')
# (3, 'study')
# (3, 'still')
# (3, 'something')
# (3, 'since')
# (3, 'rs')
# (3, 'recommend')
# (3, 'received')
# (3, 'really')
# (3, 'overall')
# (3, 'option')
# (3, 'name')
# (3, 'lot')
# (3, 'looks')
# (3, 'less')
# (3, 'legs')
# (3, 'keep')
# (3, 'hold')
# (3, 'high')
# (3, 'height')
# (3, 'got')
# (3, 'fine')
# (3, 'excellent')
# (3, 'enough')
# (3, 'easily')
# (3, 'didn')
# (3, 'delivery')
# (3, 'cost')
# (3, 'compared')
# (3, 'cheap')
# (3, 'bit')
# (3, 'better')
# (3, 'best')
# (3, 'around')
# (2, 'year')
# (2, 'wobbles')
# (2, 'value')
# (2, 'useful')
# (2, 'tv')
# (2, 'try')
# (2, 'time')
# (2, 'though')
# (2, 'think')
# (2, 'thanks')
# (2, 'take')
# (2, 'tables')
# (2, 'suggest')
# (2, 'star')
# (2, 'stand')
# (2, 'spare')
# (2, 'size')
# (2, 'sitting')
# (2, 'side')
# (2, 'shop')
# (2, 'shaky')
# (2, 'shakes')
# (2, 'sent')
# (2, 'seller')
# (2, 'scratches')
# (2, 'room')
# (2, 'return')
# (2, 'reading')
# (2, 'purchased')
# (2, 'position')
# (2, 'portable')
# (2, 'poor')
# (2, 'new')
# (2, 'mouse')
# (2, 'material')
# (2, 'mate')
# (2, 'manufacturer')
# (2, 'make')
# (2, 'looking')
# (2, 'know')
# (2, 'issue')
# (2, 'india')
# (2, 'inches')
# (2, 'holds')
# (2, 'hard')
# (2, 'happy')
# (2, 'grip')
# (2, 'great')
# (2, 'go')
# (2, 'give')
# (2, 'full')
# (2, 'fragile')
# (2, 'floor')
# (2, 'fix')
# (2, 'five')
# (2, 'ease')
# (2, 'durable')
# (2, 'don')
# (2, 'dining')
# (2, 'desk')
# (2, 'design')
# (2, 'described')
# (2, 'cup')
# (2, 'corner')
# (2, 'convenient')
# (2, 'comfortable')
# (2, 'colour')
# (2, 'clip')
# (2, 'carrying')
# (2, 'care')
# (2, 'blue')
# (2, 'bent')
# (2, 'base')
# (2, 'attachment')
# (2, 'always')
# (2, 'adjustable')
# (1, 'yet')
# (1, 'yesterday')
# (1, 'wrote')
# (1, 'write')
# (1, 'wow')
# (1, 'worthy')
# (1, 'worst')
# (1, 'world')
# (1, 'workmanship')
# (1, 'wondering')
# (1, 'wobbly')
# (1, 'without')
# (1, 'whose')
# (1, 'well')
# (1, 'week')
# (1, 'weak')
# (1, 'way')
# (1, 'water')
# (1, 'wasted')
# (1, 'waste')
# (1, 'want')
# (1, 've')
# (1, 'various')
# (1, 'valuble')
# (1, 'valuable')
# (1, 'user')
# (1, 'unusuable')
# (1, 'unsure')
# (1, 'uncomfortable')
# (1, 'unable')
# (1, 'tubular')
# (1, 'tried')
# (1, 'tray')
# (1, 'today')
# (1, 'thought')
# (1, 'third')
# (1, 'things')
# (1, 'therefore')
# (1, 'thank')
# (1, 'term')
# (1, 'technology')
# (1, 'tea')
# (1, 'takes')
# (1, 'tactics')
# (1, 'tablets')
# (1, 'tablemates')
# (1, 'tablemate')
# (1, 'surrendered')
# (1, 'surface')
# (1, 'sure')
# (1, 'support')
# (1, 'supplier')
# (1, 'suitable')
# (1, 'suggestion')
# (1, 'suggested')
# (1, 'studies')
# (1, 'stubbornvery')
# (1, 'strongly')
# (1, 'steady')
# (1, 'stay')
# (1, 'stashed')
# (1, 'starting')
# (1, 'started')
# (1, 'standing')
# (1, 'stable')
# (1, 'stability')
# (1, 'spillage')
# (1, 'specifications')
# (1, 'space')
# (1, 'son')
# (1, 'sometimes')
# (1, 'solve')
# (1, 'sold')
# (1, 'smaller')
# (1, 'small')
# (1, 'slowly')
# (1, 'slight')
# (1, 'sliding')
# (1, 'sits')
# (1, 'simply')
# (1, 'simple')
# (1, 'shipping')
# (1, 'shared')
# (1, 'setting')
# (1, 'service')
# (1, 'serves')
# (1, 'seen')
# (1, 'seems')
# (1, 'seeing')
# (1, 'see')
# (1, 'second')
# (1, 'scratched')
# (1, 'says')
# (1, 'say')
# (1, 'satisfied')
# (1, 'rupees')
# (1, 'rubber')
# (1, 'rotating')
# (1, 'roller')
# (1, 'rod')
# (1, 'ripoff')
# (1, 'review')
# (1, 'returning')
# (1, 'result')
# (1, 'request')
# (1, 'replacement')
# (1, 'replaced')
# (1, 'related')
# (1, 'regularly')
# (1, 'regular')
# (1, 'refurbished')
# (1, 'refund')
# (1, 're')
# (1, 'ratings')
# (1, 'rather')
# (1, 'quick')
# (1, 'qualitydespite')
# (1, 'putting')
# (1, 'purchasing')
# (1, 'provided')
# (1, 'proper')
# (1, 'promising')
# (1, 'progressively')
# (1, 'products')
# (1, 'probably')
# (1, 'priced')
# (1, 'pressure')
# (1, 'positives')
# (1, 'planning')
# (1, 'place')
# (1, 'person')
# (1, 'people')
# (1, 'parts')
# (1, 'paint')
# (1, 'page')
# (1, 'packaging')
# (1, 'overpriced')
# (1, 'original')
# (1, 'ordered')
# (1, 'okay')
# (1, 'ok')
# (1, 'obviously')
# (1, 'now')
# (1, 'nothing')
# (1, 'note')
# (1, 'niece')
# (1, 'never')
# (1, 'negatives')
# (1, 'negative')
# (1, 'must')
# (1, 'multipurpose')
# (1, 'moves')
# (1, 'mostly')
# (1, 'morever')
# (1, 'month')
# (1, 'modify')
# (1, 'mobility')
# (1, 'mobile')
# (1, 'middle')
# (1, 'mentioned')
# (1, 'may')
# (1, 'match')
# (1, 'marketing')
# (1, 'many')
# (1, 'manageable')
# (1, 'mainly')
# (1, 'machine')
# (1, 'm')
# (1, 'lower')
# (1, 'loved')
# (1, 'loosing')
# (1, 'look')
# (1, 'lol')
# (1, 'logic')
# (1, 'lock')
# (1, 'locally')
# (1, 'little')
# (1, 'list')
# (1, 'lil')
# (1, 'least')
# (1, 'last')
# (1, 'laptops')
# (1, 'lap')
# (1, 'knowingly')
# (1, 'kinda')
# (1, 'keyboard')
# (1, 'keeper')
# (1, 'item')
# (1, 'issues')
# (1, 'isnt')
# (1, 'isn')
# (1, 'iron')
# (1, 'intial')
# (1, 'inspire')
# (1, 'indicated')
# (1, 'indian')
# (1, 'include')
# (1, 'incline')
# (1, 'improvements')
# (1, 'impression')
# (1, 'imported')
# (1, 'images')
# (1, 'hoping')
# (1, 'home')
# (1, 'holding')
# (1, 'holder')
# (1, 'hinges')
# (1, 'hinge')
# (1, 'helpful')
# (1, 'heights')
# (1, 'heavy')
# (1, 'hardly')
# (1, 'handy')
# (1, 'hands')
# (1, 'hand')
# (1, 'guess')
# (1, 'ground')
# (1, 'gripped')
# (1, 'gradual')
# (1, 'grade')
# (1, 'gone')
# (1, 'glass')
# (1, 'giving')
# (1, 'gives')
# (1, 'given')
# (1, 'gi')
# (1, 'front')
# (1, 'friends')
# (1, 'friendly')
# (1, 'found')
# (1, 'foreign')
# (1, 'food')
# (1, 'folded')
# (1, 'flexibility')
# (1, 'flat')
# (1, 'fitting')
# (1, 'fit')
# (1, 'firmly')
# (1, 'finishing')
# (1, 'find')
# (1, 'fill')
# (1, 'fell')
# (1, 'feels')
# (1, 'feeling')
# (1, 'feel')
# (1, 'feature')
# (1, 'family')
# (1, 'fallen')
# (1, 'face')
# (1, 'extent')
# (1, 'expensive')
# (1, 'expectations')
# (1, 'expect')
# (1, 'everyday')
# (1, 'even')
# (1, 'etc')
# (1, 'enuf')
# (1, 'enterprises')
# (1, 'eating')
# (1, 'durability')
# (1, 'duplicate')
# (1, 'drawback')
# (1, 'donr')
# (1, 'done')
# (1, 'doesn')
# (1, 'dint')
# (1, 'difference')
# (1, 'diary')
# (1, 'dia')
# (1, 'details')
# (1, 'description')
# (1, 'depending')
# (1, 'depend')
# (1, 'definitely')
# (1, 'defects')
# (1, 'defect')
# (1, 'decent')
# (1, 'deal')
# (1, 'days')
# (1, 'date')
# (1, 'damages')
# (1, 'damaged')
# (1, 'crap')
# (1, 'couple')
# (1, 'counterparts')
# (1, 'costly')
# (1, 'corporate')
# (1, 'connects')
# (1, 'connector')
# (1, 'complicated')
# (1, 'commnets')
# (1, 'comes')
# (1, 'color')
# (1, 'coffee')
# (1, 'coaster')
# (1, 'clamp')
# (1, 'china')
# (1, 'cheaper')
# (1, 'changes')
# (1, 'chair')
# (1, 'carry')
# (1, 'capture')
# (1, 'capable')
# (1, 'cant')
# (1, 'bushes')
# (1, 'built')
# (1, 'brought')
# (1, 'broad')
# (1, 'brim')
# (1, 'break')
# (1, 'bought')
# (1, 'bottom')
# (1, 'bore')
# (1, 'books')
# (1, 'body')
# (1, 'blindly')
# (1, 'big')
# (1, 'benefit')
# (1, 'bending')
# (1, 'bend')
# (1, 'bee')
# (1, 'bed')
# (1, 'available')
# (1, 'attached')
# (1, 'assembly')
# (1, 'arush')
# (1, 'arrived')
# (1, 'apprehensive')
# (1, 'appreciate')
# (1, 'amazing')
# (1, 'already')
# (1, 'along')
# (1, 'ages')
# (1, 'aged')
# (1, 'adjusted')
# (1, 'add')
# (1, 'accumulates')
# (1, 'according')
# (1, 'absolutely')
# (1, 'able')
# (1, 'ability')

# %%
xyz = open('tablematereviews.txt', 'w+')

# %%
xyz.seek(0)
# Out:
# 0

# %%
xyz.read()
# Out:
# 'using since months colour good buy table got bent use don t buy long term purpose poor product wasted money option return crap suggest purchase planning use table laptop assemble table shakes lot typing laptop therefore depend obviously keep machine starting price rs table simple logic using table five months two tables one imported less sturdy second one table excellent name suggested sturdy compared tables however one suggestion supplier table fallen one two rotating hinges attached table broken however replaced gi fitting locally available problem didn t face foreign make whose design excellent request modify design include spare list third grade cheap marketing tactics using made india name product tablemate s cheap ripoff expensive price just name difference hardly improvements table wobbles way much use returning product multi table just received standing expectations color perfect blue like ordered s sturdy light weight easy assemble light carrying overall good product purpose food reading writing just got yet know long will stay feel will solve purpose long time buy product waste money days purchase plastic attachment broken worst attachment technology used never recommend seller sent damaged product knowingly defects clip table found broken know broken still sent spare clip can assemble time blue paint gone parts scratches giving feeling used one positives product good usage mainly laptop usage laptop inches gives enuf room comfortable ability type without shaking etc use hard use mouse along table though negatives surface doesn t good grip hold lap sliding laptop bottom good gripped rubber may problem thanks quite useful table use laptop front tv however table quite shaky bit wobbly legs tray also bent one side slight gradual incline nothing unusuable though still holds laptops tablets well however water easily accumulates one corner putting something like tea coffee cup full brim result spillage one side purchased multi table amazon last week absolutely problem setting using described product page multi table strong enough hold laptop cup holder comes handy working long manufacturer provided bushes grip legs place table firmly floor best product price feature definitely recommend family friends table sturdy use think t table moves lot typing laptop keyboard assembly big deal dint find promising also option return refund option replacement seller arush enterprises wrote thank note says manufacturer product tried hard make best still one perfect world wow already surrendered issues lol son using couple months now can used sitting bed proper chair product user friendly complicated can adjusted various height depending person sits serves purpose quality flexibility good enough however table quite shaky probably issue floor will try fix delivery packaging amazon just amazing intial impression good seen many tablemates one quite good body built good qualitydespite negative commnets ratings can go product valuble product purchase yesterday received two multi table s really worth good quality s strong s better tv product s better shop material niece s happy just month use weight light corporate laptop mouse small diary table started bending middle slowly looks unable take weight hand typing sure use months good strong mobile durable takes much space bee using eating writing working laptop given price around rs cheaper changes made fix table top iron stand good stashed corner stand table top folded good laptop use easy assemble portable donr expect capable carrying heavy things cant keep books purchased today see lil bend think defect say worth rs must take care fragile type much use want table study purpose something related s steady s always shaking base support weak hoping table helpful studies since shaking always didn t like use arrived broken scratched hinge type plastic connector connects table top table legs broken unsure done shipping seems quite fragile nice product received delivery date appreciate amazon s servi ...

# %%
xyz.close()

# %%
pwd
# Out:
# 'C:\\Users\\V Sudheer Kumar'

# %%
# WordCloud can be performed on the string inputs. That is the reason we have combined
# entire reviews into single paragraph
# Simple word cloud

# %%
wordcloud_ip = WordCloud(
                background_color='black',
                width=1800,
                height=1400
                ).generate(ip_rev_string)

# %%
plt.imshow(wordcloud_ip)
fig=plt.figure(figsize=(20,10),dpi=300)

# %%
# positive words # Choose the path for +ve words stored in system
with open("C:\\Users\\V Sudheer Kumar\\Documents\\poswords.txt","r") as pos:
    poswords = pos.read().split("\n")

# %%
poswords = poswords[36:]

# %%
# negative words # Choose the path for -ve words stored in system
with open("C:\\Users\\V Sudheer Kumar\\Documents\\negwords.txt","r") as neg:
    negwords = neg.read().split("\n")

# %%
negwords = negwords[37:]

# %%
# negative word cloud
# Choosing the only words which are present in negwords
ip_neg_in_neg = " ".join([w for w in ip_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                      ).generate(ip_neg_in_neg)

# %%
plt.figure(1)
plt.imshow(wordcloud_neg_in_neg)

# %%
# positive word cloud
# Choosing the only words which are present in poswords
ip_pos_in_pos = " ".join([w for w in ip_reviews_words if w in poswords])

wordcloud_pos_in_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                      ).generate(ip_pos_in_pos)

# %%
plt.figure(2)
plt.imshow(wordcloud_pos_in_pos)

# %%
# With white background

# %%
# negative word cloud
# Choosing the only words which are present in negwords
ip_neg_in_neg = " ".join([w for w in ip_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='white',
                      width=1800,
                      height=1400
                      ).generate(ip_neg_in_neg)

# %%
plt.figure(1)
plt.imshow(wordcloud_neg_in_neg)

# %%
# positive word cloud
# Choosing the only words which are present in poswords
ip_pos_in_pos = " ".join([w for w in ip_reviews_words if w in poswords])

wordcloud_pos_in_pos = WordCloud(
                      background_color='white',
                      width=1800,
                      height=1400
                      ).generate(ip_pos_in_pos)

# %%
plt.figure(2)
plt.imshow(wordcloud_pos_in_pos)
